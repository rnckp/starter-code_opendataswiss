# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for dataset with identifier* **283536cf-8f7e-4286-afd6-36635a86bae6@bundesamt-fur-meteorologie-und-klimatologie-meteoschweiz**

# %% [markdown]
# ## Dataset
# # **Automatische Turmstationen – Messwerte**

# %% [markdown]
# ## Description
#
# Temperatur, Wind, Sonnenschein, Feuchte und Strahlung – pro Station – Werte alle 10 Minuten ('t'), stündlich ('h'), täglich ('d'), monatlich ('m') und jährlich ('y') – seit Mitternacht ('now'), vom aktuellen Jahr bis gestern ('recent'), seit Messbeginn in Zehnjahresschritten ('historical'). Wenn Sie stündliche, tägliche, monatliche oder jährliche Werte benötigen, empfehlen wir Ihnen dringend, die entsprechende Auflösung herunterzuladen.

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/automatische-turmstationen-messwerte)<br>
# [Direct link by Bundesamt für Meteorologie und Klimatologie MeteoSchweiz for dataset](https://www.meteoschweiz.admin.ch/service-und-publikationen/service/open-data.html)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Bundesamt für Meteorologie und Klimatologie MeteoSchweiz`
# - **Organization.url** `https://www.meteoschweiz.admin.ch`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['atmospharische-bedingungen', 'meteorologisch-geografische-kennwerte', 'lufttemperatur', 'wetter', 'luftfeuchtigkeit', 'wind', 'meteorologischer-parameter', 'luft-atmosphare', 'klimatologie', 'meteorologie', 'strahlung', 'sonnenscheindauer', 'bgdi-bundesgeodaten-infrastruktur', 'opendata']`
# - **Issued** `2025-05-20T00:00:00`
# - **Metadata_created** `2025-05-21T02:18:36.519617`
# - **Metadata_modified** `2025-12-19T01:13:35.092489`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : bcf5be38-41d2-4664-abc0-4a5a0bf54177
# Description              : Alle Parameter haben eine eindeutige Kennung, die von der zeitlichen Auflösung abhängig ist. Diese Ressource enthält eine Liste aller Parameterkennungen mit Erläuterung, Zeitintervall, Dezimalstellen, Datentyp und Masseinheit.
# Issued                   : 2025-05-20T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/ch.meteoschweiz.ogd-smn-tower/ogd-smn-tower_meta_parameters.csv')

# Distribution 1
# Package_id               : bcf5be38-41d2-4664-abc0-4a5a0bf54177
# Description              : Alle Stationen haben eine aus drei Buchstaben bestehende Kennung (z.B. "BER" für "Bern/Zollikofen" oder "LUG" für "Lugano"). Diese Ressource enthält eine Liste aller Stationskennungen mit Namen, Kanton, Wigos ID, Stationstyp, Höhe, Koordinaten, Ausrichtung und URL der Stationsdetailseiten.
# Issued                   : 2025-05-20T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/ch.meteoschweiz.ogd-smn-tower/ogd-smn-tower_meta_stations.csv')

# Distribution 2
# Package_id               : bcf5be38-41d2-4664-abc0-4a5a0bf54177
# Description              : Temperatur, Wind, Sonnenschein, Feuchte und Strahlung – pro Station – Werte alle 10 Minuten ('t'), stündlich ('h'), täglich ('d'), monatlich ('m') und jährlich ('y') – seit Mitternacht ('now'), vom aktuellen Jahr bis gestern ('recent'), seit Messbeginn in Zehnjahresschritten ('historical'). Wenn Sie stündliche, tägliche, monatliche oder jährliche Werte benötigen, empfehlen wir Ihnen dringend, die entsprechende Auflösung herunterzuladen.
# Issued                   : 2025-05-20T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/api/stac/v1/collections/ch.meteoschweiz.ogd-smn-tower')

# Distribution 3
# Package_id               : bcf5be38-41d2-4664-abc0-4a5a0bf54177
# Description              : Diese Ressource enthält eine Liste aller Stationen und Parameter mit Start- und Enddatum der Messungen.
# Issued                   : 2025-05-20T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/ch.meteoschweiz.ogd-smn-tower/ogd-smn-tower_meta_datainventory.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata.en@meteoswiss.ch | opendata.en@meteoswiss.ch
