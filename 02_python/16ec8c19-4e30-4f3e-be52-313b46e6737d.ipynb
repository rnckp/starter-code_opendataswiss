# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **152adc29-96fd-4616-851c-39d3e30d159d@envidat**

# %% [markdown]
# ## Dataset
# # **Figures perspective urban beekeeping**

# %% [markdown]
# ## Description

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/figures-perspective-urban-beekeeping)<br>
# [Direct link by EnviDat: das Umwelt-Datenportal for dataset](https://www.envidat.ch/#/metadata/figures-perspective-urban-beekeeping)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `EnviDat`
# - **Organization.display_name.de** `EnviDat: das Umwelt-Datenportal`
# - **Organization.url** `https://www.envidat.ch/`
# - **Maintainer** `Joan Casanelles`
# - **Maintainer_email** `joan.casanelles@wsl.ch`
# - **Keywords.de** `[]`
# - **Issued** `2024-03-18T13:13:58+00:00`
# - **Metadata_created** `2024-08-17T03:59:58.864496`
# - **Metadata_modified** `2025-08-23T03:42:29.774202`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`12` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-04-18T08:14:05+00:00
# Modified                 : 2024-04-18T10:36:31+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/efd9c5a4-9b8f-4473-b5c6-c6c6c65c22c5')

# Distribution 1
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-05-14T14:42:32+00:00
# Modified                 : 2024-05-14T16:43:18+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/979f7e0b-d069-4f73-8978-da6a25021681')

# Distribution 2
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-03-18T13:27:31+00:00
# Modified                 : 2024-08-12T16:35:24+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/7a0a508a-5b79-4eb6-810d-d75c7aac1ea4')

# Distribution 3
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-05-14T14:40:27+00:00
# Modified                 : 2024-05-14T16:41:17+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/5f514458-36af-4c5c-a3b2-fefe670ebdb3')

# Distribution 4
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-03-18T14:27:17+00:00
# Modified                 : 2024-11-27T10:31:13+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/a5320430-d384-4451-8cd7-5dfc49a9b427')

# Distribution 5
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-03-18T16:23:07+00:00
# Modified                 : 2024-11-27T11:20:04+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/7ab40a8e-a8b5-45e0-a56c-b3ef34373ed9')

# Distribution 6
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-03-18T13:25:37+00:00
# Modified                 : 2024-11-27T10:31:03+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/5ba02a31-5914-4bba-ad65-58cb93030b07')

# Distribution 7
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-11-27T10:18:08+00:00
# Modified                 : 2024-11-28T15:42:49+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/017ec9fb-051e-44b5-802b-c2a9ebb519f3')

# Distribution 8
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-03-18T16:10:56+00:00
# Modified                 : 2024-11-27T11:17:49+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/40fc5176-f9bd-4406-bdaa-ec5777d59bc7')

# Distribution 9
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-11-27T10:15:38+00:00
# Modified                 : 2024-11-28T15:42:42+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/2cbc89cf-9a61-470d-9782-d06683905aec')

# Distribution 10
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-04-18T08:36:41+00:00
# Modified                 : 2024-04-18T10:46:49+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/1362115c-fced-4573-af08-2923b1fcfe5c')

# Distribution 11
# Package_id               : 16ec8c19-4e30-4f3e-be52-313b46e6737d
# Description              : 
# Issued                   : 2024-04-18T08:04:28+00:00
# Modified                 : 2024-08-12T16:35:11+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/figures-perspective-urban-beekeeping/resource/bb5d9722-2054-4cf3-8c14-8233f78c367a')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: envidat@wsl.ch | EnviDat Support
