# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **604ed5f6-2307-44e5-a286-72204af5e837@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Grundstückspreise (Median) der im Freihandkauf umgesetzten bebauten Grundstücke nach Stadtquartier und Zonenart (nur BZO99)**

# %% [markdown]
# ## Description
#
#
# Diese Daten beinhalten die Medianpreise pro Quadratmeter Bauland von gehandelten Grundstücken in der Stadt Zürich nach Handänderungsjahr, Hanänderungsart, Stadtquartier und Zonenart. Aufgrund der Einführung der neuen Bau- und Zonenordnung im November 2018 endet die Zeitreihe im November 2018.
#
# Bitte beachten Sie für das korrekte Verständnis zu den Daten die unten aufgeführten weiteren Erläuterungen in der Rubrik **«Bemerkungen»**.

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/grundstuckspreise-median-der-im-freihandkauf-umgesetzten-bebauten-grundstucke-nach-stadtqu-2018)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/bau_hae_preis_quartier_zonenart_bzo99_seit2009_od5148)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Statistik Stadt Zürich, Präsidialdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['bau-und-zonenordnung', 'bebauungsart', 'bzo', 'handaenderungen', 'liegenschaftenhandel', 'median', 'sachdaten', 'sasa', 'tabelle', 'zeitreihe']`
# - **Issued** `2023-10-15T00:00:00`
# - **Metadata_created** `2023-11-22T02:45:14.524179`
# - **Metadata_modified** `2026-02-15T00:30:46.523141`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 7220b3d5-42fa-4cf8-94cd-1eba5d8e25e5
# Description              : 
# Issued                   : 2023-11-21T09:32:04.748946
# Modified                 : 2026-02-14T21:08:06.214988
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/bau_hae_preis_quartier_zonenart_bzo99_seit2009_od5148/download/BAU514OD5148.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
