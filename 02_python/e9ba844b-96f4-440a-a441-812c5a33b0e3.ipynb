# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **f27d0c4b-ffeb-4ae3-afe5-797ec9101647@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Neuerstellte Wohnungen nach Art Ersatzbau, Statistischer Zone und Eigentumsgruppe seit  2000**

# %% [markdown]
# ## Description
#
# Der Datensatz enthält die neuerstellten Wohnungen nach Art des Ersatzbaus (Wohnersatz, Umnutzung, auf unbebauter Fläche), differenziert nach Eigentumsgruppe und Statistischer Zone/Stadtquartier/Stadtkreis. Die Daten sind ab dem Jahr 2000 verfügbar.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/neuerstellte-wohnungen-nach-art-ersatzbau-statistischer-zone-und-eigentumsgruppe-seit-2000)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/bau_neubau_whg_ersatzbauart_eigentumsgruppe_statzone_seit2000_od5324)

# %% [markdown]
# ## Metadata
# - **Publisher** `Statistik Stadt Zürich, Präsidialdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['zeitreihe', 'abbruch', 'quartier', 'tabelle', 'sasa', 'bautaetigkeit', 'erneuerung', 'umbau', 'grundangebot-bau', 'wohnungen', 'wohnen', 'bauwesen', 'sachdaten']`
# - **Issued** `2020-04-07T00:00:00`
# - **Metadata_created** `2020-04-07T07:45:33.416690`
# - **Metadata_modified** `2023-01-16T00:50:50.844154`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : e9ba844b-96f4-440a-a441-812c5a33b0e3
# Description              : 
# Issued                   : 2020-04-06T00:00:00
# Modified                 : 2023-01-15T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/bau_neubau_whg_ersatzbauart_eigentumsgruppe_statzone_seit2000_od5324/download/BAU532OD5324.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
