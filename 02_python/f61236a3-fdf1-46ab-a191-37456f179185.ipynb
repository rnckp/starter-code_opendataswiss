# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **c0fe641c-4b38-4234-b499-023fa2d86dc1@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Stündlich aktualisierte Luftqualitätsmessungen, seit 1983**

# %% [markdown]
# ## Description
#
#
# Dieses Dataset umfasst **Stundenmesswerte seit 1983 bis zur letzten aktuellen Stunde**, aufgeteilt in Jahresdateien. Darin enthalten sind die **Stundenmittelwerte** des entsprechenden Jahres für die Stationen Stampfenbachstrasse, Schimmelstrasse, Rosengartenstrasse und Heubeeribüel. Gemessen wird Ozon (O3), Stickoxide (NOx), Stickstoffmonoxid (NO), Stickstoffdioxid (NO2), Feinstaub (PM10 und PM2.5), Kohlenmonoxid (CO) und Schwefeldioxid (SO2) wo jeweils in genügender Qualität vorhanden.
#
# Die Stundenmittelwerte des laufenden Jahres werden jeweils 30 Minuten nach der vollen Stunde aktualisiert.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/stundlich-aktualisierte-luftqualitatsmessungen-seit-19831)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte)

# %% [markdown]
# ## Metadata
# - **Publisher** `Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['kohlenmonoxid', 'feinstaub', 'pm25', 'luftschadstoffe', 'stickstoffmonoxid', 'so2', 'nox', 'schadstoffe', 'stickstoffdioxid', 'dtoer', 'luft', 'stickoxide', 'schwefeldioxid', 'no2', 'co', 'o3', 'ozon', 'digitale-transparenz-im-oeffentlichen-raum', 'echtzeit', 'no', 'messwerte', 'tabelle', 'pm10', 'zeitreihe', 'luftqualitat', 'sachdaten']`
# - **Issued** `nan`
# - **Metadata_created** `2024-11-28T02:52:13.957304`
# - **Metadata_modified** `2024-12-06T02:33:51.878887`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`42` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:05.759595
# Modified                 : 2024-06-12T01:39:02.536743
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2008.csv')

# Distribution 1
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:14.600349
# Modified                 : 2024-06-12T01:39:16.297809
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2014.csv')

# Distribution 2
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:56.745439
# Modified                 : 2024-06-12T01:38:53.448071
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2004.csv')

# Distribution 3
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:40.279327
# Modified                 : 2024-06-12T01:38:42.400313
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1999.csv')

# Distribution 4
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:59.260611
# Modified                 : 2024-06-12T01:38:19.669826
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1988.csv')

# Distribution 5
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:58.131461
# Modified                 : 2024-06-12T01:38:56.097703
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2005.csv')

# Distribution 6
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:16.481614
# Modified                 : 2024-06-12T01:39:18.880422
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2015.csv')

# Distribution 7
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:29.376602
# Modified                 : 2024-06-12T01:39:33.067872
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2021.csv')

# Distribution 8
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:19.043710
# Modified                 : 2024-06-12T01:39:21.240752
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2016.csv')

# Distribution 9
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:31.559236
# Modified                 : 2024-06-12T01:38:34.379271
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1995.csv')

# Distribution 10
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:46.184952
# Modified                 : 2024-06-12T01:38:08.451280
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1984.csv')

# Distribution 11
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:43.585937
# Modified                 : 2024-06-12T01:38:46.744155
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2001.csv')

# Distribution 12
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:34.691157
# Modified                 : 2024-06-12T01:38:36.337538
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1996.csv')

# Distribution 13
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:29.718335
# Modified                 : 2024-06-12T01:38:32.307446
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1994.csv')

# Distribution 14
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:08.983088
# Modified                 : 2024-06-12T01:39:07.338907
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2010.csv')

# Distribution 15
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:10.784756
# Modified                 : 2024-06-12T01:38:24.204034
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1990.csv')

# Distribution 16
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:41.881520
# Modified                 : 2024-06-12T01:38:44.567661
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2000.csv')

# Distribution 17
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:11.820158
# Modified                 : 2024-06-12T01:39:11.799881
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2012.csv')

# Distribution 18
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:31.586625
# Modified                 : 2024-06-12T01:39:35.569357
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2022.csv')

# Distribution 19
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:00.673649
# Modified                 : 2024-06-12T01:38:21.954258
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1989.csv')

# Distribution 20
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:02.443561
# Modified                 : 2024-06-12T01:38:58.141390
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2006.csv')

# Distribution 21
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:36.103595
# Modified                 : 2024-06-12T01:38:38.394035
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1997.csv')

# Distribution 22
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:49.634445
# Modified                 : 2024-06-12T01:38:14.830260
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1986.csv')

# Distribution 23
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:21.074088
# Modified                 : 2024-06-12T01:39:23.727217
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2017.csv')

# Distribution 24
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:56.575652
# Modified                 : 2024-06-12T01:38:17.470992
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1987.csv')

# Distribution 25
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:10.304165
# Modified                 : 2024-06-12T01:39:09.507606
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2011.csv')

# Distribution 26
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:13.216593
# Modified                 : 2024-06-12T01:39:14.071695
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2013.csv')

# Distribution 27
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:07.516865
# Modified                 : 2024-06-12T01:39:05.264202
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2009.csv')

# Distribution 28
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:47.150993
# Modified                 : 2024-06-12T01:38:11.510165
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1985.csv')

# Distribution 29
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:04.208704
# Modified                 : 2024-06-12T01:39:00.301552
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2007.csv')

# Distribution 30
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:10:43.338162
# Modified                 : 2024-06-12T01:38:06.203002
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1983.csv')

# Distribution 31
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:55.287006
# Modified                 : 2024-06-12T01:38:51.233694
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2003.csv')

# Distribution 32
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:25.694191
# Modified                 : 2024-06-12T01:39:28.498405
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2019.csv')

# Distribution 33
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:26.802682
# Modified                 : 2024-06-12T01:38:28.342249
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1992.csv')

# Distribution 34
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:25.418930
# Modified                 : 2024-06-12T01:38:26.322084
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1991.csv')

# Distribution 35
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:54.104214
# Modified                 : 2024-06-12T01:38:48.723628
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2002.csv')

# Distribution 36
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:27.754225
# Modified                 : 2024-06-12T01:39:30.603778
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2020.csv')

# Distribution 37
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:33.354601
# Modified                 : 2024-06-12T01:39:37.941341
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2023.csv')

# Distribution 38
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:28.220749
# Modified                 : 2024-06-12T01:38:30.395178
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1993.csv')

# Distribution 39
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:22.883767
# Modified                 : 2024-06-12T01:39:25.979402
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2018.csv')

# Distribution 40
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:11:37.293678
# Modified                 : 2024-06-12T01:38:40.319395
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1998.csv')

# Distribution 41
# Package_id               : f61236a3-fdf1-46ab-a191-37456f179185
# Description              : 
# Issued                   : 2024-11-27T11:12:39.434258
# Modified                 : 2024-06-12T01:39:40.436172
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2024.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
