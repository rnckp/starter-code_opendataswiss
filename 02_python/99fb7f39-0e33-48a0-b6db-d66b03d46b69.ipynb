# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **9ea4d28a-59f1-47e2-8043-0d8956705950@kanton-zug**

# %% [markdown]
# ## Dataset
# # **Überbaute Fläche pro Person**

# %% [markdown]
# ## Description
#
# Überbaute Fläche pro Person aller Schweizer Kantone, 2018.
#
# Die überbaute Fläche ist in Hektar, die überbaute Fläche pro Person in m² angegeben. Die überbaute Fläche pro Person zeigt die bauliche Verdichtung nach Kantonen an (je niedriger, desto verdichteter). Die überbaute Fläche wird ermittelt, indem die Summe aus Industrie- und Gewerbearealen, Gebäudearealen, Verkehrsflächen und besonderen Siedlungsflächen in m² durch die ständige Wohnbevölkerung geteilt wird.
#
# (QUELLE: Bundesamt für Statistik, Arealstatistik und STATPOP)

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/uberbaute-flache-pro-person)<br>
# [Direct link by Kanton Zug for dataset](https://www.zg.ch/behoerden/gesundheitsdirektion/statistikfachstelle/themen/raum-und-umwelt/raum)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Kanton Zug`
# - **Organization.url** `None provided`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['gewerbeareale', 'gebaudeareale', 'verkehrsflachen', 'siedlungsflachen']`
# - **Issued** `2024-12-02T00:00:00`
# - **Metadata_created** `2024-11-29T12:18:31.089244`
# - **Metadata_modified** `2026-02-03T07:12:35.204409`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 99fb7f39-0e33-48a0-b6db-d66b03d46b69
# Description              : 
# Issued                   : None
# Modified                 : 2024-10-15T12:14:22.537000+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.zg.ch/store/1/resource/277')

# Distribution 1
# Package_id               : 99fb7f39-0e33-48a0-b6db-d66b03d46b69
# Description              : 
# Issued                   : None
# Modified                 : 2024-12-05T12:50:45.950000+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.zg.ch/store/1/resource/1341')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata@zg.ch | Open Data Zug
