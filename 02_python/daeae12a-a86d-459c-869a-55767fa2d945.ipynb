# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **lebensmittelkontrolle@bundesamt-fur-lebensmittelsicherheit-und-veterinaerwesen-blv**

# %% [markdown]
# ## Dataset
# # **Lebensmittelkontrolle**

# %% [markdown]
# ## Description
#
# Die kantonalen Lebensmittelvollzugsbehörden und das Fürstentum Liechtenstein kontrollieren Betriebe und Lebensmittel und melden die Ergebnisse an das BLV. Die meisten amtlichen Kontrollen erfolgen risikobasiert, also gezielt dort, wo das höchste Risiko für Abweichungen von den lebensmittelrechtlichen Vorgaben vermutet wird. Damit sorgen diese Kontrollen für sichere und qualitativ hochwertige Lebensmittel.
#
# Da sich die Datenübermittlung noch in der Entwicklungsphase befindet, sind die verfügbaren Ergebnisse auf bestimmte Untersuchungsbereiche beschränkt.
#
# Eine Lebensmittelprobe ist konform, wenn sie den gesetzlichen Vorgaben entspricht. Werden diese nicht eingehalten, gilt die Probe als nicht konform und wird beanstandet. In bestimmten Fällen ist keine Konformitätsbewertung möglich, da zu einem bestimmten Sachverhalt noch keine gesetzlichen Vorgaben bestehen. Dann wird das Ergebnis als nicht bewertet gemeldet. Diese Werte erscheinen nicht in den Visualisierungen.
#
# Nicht alle Untersuchungen erscheinen in den Daten: So führen zum Beispiel pendente Schnittstellenoptimierungen und uneinheitliche Erfassung von Werten unterhalb der Nachweisgrenze in den Laborinformationssystemen der Kantone dazu, dass gewisse Ergebnisse nicht an das BLV übermittelt werden.
#
# An einer Probe können mehrere Untersuchungen (Analysen auf verschiedene Substanzen oder Eigenschaften) durchgeführt werden. Das bedeutet, dass es pro Probe konforme und nicht konforme Untersuchungen geben kann, welche dann auch so in den Auswertungen erscheinen. Mit den von den Kantonen und dem Fürstentum Liechtenstein gemeldeten Daten kann hingegen keine Aussage über den Anteil nicht konformer Proben getroffen werden.
#
# https://www.dashboard.blv.admin.ch/nutrition/food-safety/food-control

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/lebensmittelkontrolle)<br>
# [Direct link by Bundesamt für Lebensmittelsicherheit und Veterinärwesen BLV for dataset](https://www.dashboard.blv.admin.ch/nutrition/food-safety/food-control)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Bundesamt für Lebensmittelsicherheit und Veterinärwesen BLV`
# - **Organization.url** `http://www.blv.admin.ch/`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['lebensmittel', 'kontrolle']`
# - **Issued** `2025-05-01T00:00:00`
# - **Metadata_created** `2025-05-01T14:13:28.094692`
# - **Metadata_modified** `2026-01-28T08:11:09.943798`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`20` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_administrative_measure.csv')

# Distribution 1
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_category_of_establishment.csv')

# Distribution 2
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_control_area.csv')

# Distribution 3
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_grading.csv')

# Distribution 4
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_inspection_reason.csv')

# Distribution 5
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments_codelist_significance_of_the_establishment.csv')

# Distribution 6
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_food_establishments.csv')

# Distribution 7
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs.csv')

# Distribution 8
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_campaign.csv')

# Distribution 9
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_country_codes.csv')

# Distribution 10
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_evaluation_of_results.csv')

# Distribution 11
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_matrix.csv')

# Distribution 12
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_matrix_descriptor.csv')

# Distribution 13
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_operating_category.csv')

# Distribution 14
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_parameter.csv')

# Distribution 15
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_production_method.csv')

# Distribution 16
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_qualitative_result.csv')

# Distribution 17
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_reasons_for_collection.csv')

# Distribution 18
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_sample_extraction_part.csv')

# Distribution 19
# Package_id               : daeae12a-a86d-459c-869a-55767fa2d945
# Description              : 
# Issued                   : 
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.data.blv.admin.ch/ogd/food_control/food_control_foodstuffs_codelist_units.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: Kompetenzzentrum Daten (DCC) | data@blv.admin.ch
