# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **5cf41091-fc34-415b-acde-2ae43b187a60@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Täglich aktualisierte Luftqualitätsmessungen, seit 1983**

# %% [markdown]
# ## Description
#
#
# Dieses Dataset umfasst **Tageswerte** **seit 1983 bis zum aktuellen Vortag**, aufgeteilt in Jahresdateien und einmal als kompletter Datensatz im parquet-Format. Darin enthalten sind das maximale Stundenmittel und die Anzahl Überschreitungen des Stundenmittelgrenzwertes für Ozon und die Tagesmittel für Schwefeldioxid (SO2), Kohlenmonoxid (CO), Stickoxid (NOx), Stickstoffmonoxid (NO), Stickstoffdioxid (NO2), Feinstaub (PM10 und PM2.5) und Partikelanzahl (PN), sofern jeweils in genügender Qualität vorhanden.
#
# Die Werte des vollendeten Tages für das laufende Jahr werden jeweils 30 Minuten nach Mitternacht (UTC+1) aktualisiert.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/taglich-aktualisierte-luftqualitatsmessungen-seit-1983)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['kohlenmonoxid', 'so2', 'co', 'sachdaten', 'ozon', 'stickstoffmonoxid', 'stickoxide', 'stickstoffdioxid', 'zeitreihe', 'luftschadstoffe', 'pn', 'partikelanzahl', 'no', 'schwefeldioxid', 'tabelle', 'pm10', 'echtzeit', 'feinstaub', 'luft', 'messwerte', 'no2', 'o3', 'luftqualitat', 'schadstoffe', 'pm25', 'nox']`
# - **Issued** `2015-06-16T00:00:00`
# - **Metadata_created** `2024-11-28T02:52:05.176753`
# - **Metadata_modified** `2025-07-28T03:42:07.910323`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`43` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:27.601313
# Modified                 : 2025-07-28T02:36:08.019366
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2003.csv')

# Distribution 1
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:39.856457
# Modified                 : 2025-07-28T02:36:28.876576
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2010.csv')

# Distribution 2
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:07.060517
# Modified                 : 2025-07-28T02:35:38.168965
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1992.csv')

# Distribution 3
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:18.279748
# Modified                 : 2025-07-28T02:35:56.477606
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1999.csv')

# Distribution 4
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:24.440331
# Modified                 : 2025-07-28T02:36:02.206039
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2001.csv')

# Distribution 5
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:06.647064
# Modified                 : 2025-07-28T02:36:49.421446
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2017.csv')

# Distribution 6
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:13.084009
# Modified                 : 2025-07-28T02:37:01.289277
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2021.csv')

# Distribution 7
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:19.873024
# Modified                 : 2025-07-28T02:35:58.629442
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2000.csv')

# Distribution 8
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:25.782620
# Modified                 : 2025-07-28T02:36:04.389346
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2002.csv')

# Distribution 9
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:34.926475
# Modified                 : 2025-07-28T02:36:20.309949
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2007.csv')

# Distribution 10
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:07:56.903025
# Modified                 : 2025-07-28T02:35:19.824692
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1984.csv')

# Distribution 11
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:46.243560
# Modified                 : 2025-07-28T02:36:38.081707
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2013.csv')

# Distribution 12
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:14.081337
# Modified                 : 2025-07-28T02:35:49.183545
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1997.csv')

# Distribution 13
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:15.857705
# Modified                 : 2025-07-28T02:37:06.568038
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2023.csv')

# Distribution 14
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:41.866168
# Modified                 : 2025-07-28T02:36:31.690396
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2011.csv')

# Distribution 15
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:09.872823
# Modified                 : 2025-07-28T02:35:42.517865
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1994.csv')

# Distribution 16
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:07:57.947032
# Modified                 : 2025-07-28T02:35:21.879658
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1985.csv')

# Distribution 17
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:29.275773
# Modified                 : 2025-07-28T02:36:11.069337
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2004.csv')

# Distribution 18
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:01.510540
# Modified                 : 2025-07-28T02:35:29.274071
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1988.csv')

# Distribution 19
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:00.090589
# Modified                 : 2025-07-28T02:36:44.176817
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2015.csv')

# Distribution 20
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:12.674740
# Modified                 : 2025-07-28T02:35:47.094142
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1996.csv')

# Distribution 21
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:06.034776
# Modified                 : 2025-07-28T02:35:36.092591
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1991.csv')

# Distribution 22
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:07.838801
# Modified                 : 2025-07-28T02:36:52.156778
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2018.csv')

# Distribution 23
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:43.891301
# Modified                 : 2025-07-28T02:36:35.010251
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2012.csv')

# Distribution 24
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:15.648529
# Modified                 : 2025-07-28T02:35:52.772627
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1998.csv')

# Distribution 25
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2025-01-01T23:38:00.343303
# Modified                 : 2025-07-28T02:37:12.126631
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2025.csv')

# Distribution 26
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:02.955648
# Modified                 : 2025-07-28T02:35:31.356710
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1989.csv')

# Distribution 27
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:38.232017
# Modified                 : 2025-07-28T02:36:26.131397
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2009.csv')

# Distribution 28
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:11.347654
# Modified                 : 2025-07-28T02:36:58.672524
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2020.csv')

# Distribution 29
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:32.889193
# Modified                 : 2025-07-28T02:36:17.231289
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2006.csv')

# Distribution 30
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:05.006534
# Modified                 : 2025-07-28T02:35:33.845404
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1990.csv')

# Distribution 31
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:09.246622
# Modified                 : 2025-07-28T02:36:56.042962
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2019.csv')

# Distribution 32
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:36.269843
# Modified                 : 2025-07-28T02:36:22.668599
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2008.csv')

# Distribution 33
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:49.879432
# Modified                 : 2025-07-28T02:36:40.924897
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2014.csv')

# Distribution 34
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:14.429974
# Modified                 : 2025-07-28T02:37:03.707410
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2022.csv')

# Distribution 35
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:00.726488
# Modified                 : 2025-07-28T02:35:26.568556
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1987.csv')

# Distribution 36
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:07:55.931566
# Modified                 : 2025-07-28T02:35:17.612166
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1983.csv')

# Distribution 37
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:07:59.143877
# Modified                 : 2025-07-28T02:35:24.574536
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1986.csv')

# Distribution 38
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:08.806788
# Modified                 : 2025-07-28T02:35:40.257124
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1993.csv')

# Distribution 39
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:11.683012
# Modified                 : 2025-07-28T02:35:44.583551
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_1995.csv')

# Distribution 40
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:08:31.057890
# Modified                 : 2025-07-28T02:36:13.781934
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2005.csv')

# Distribution 41
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:02.461573
# Modified                 : 2025-07-28T02:36:46.327760
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2016.csv')

# Distribution 42
# Package_id               : 1c6876ec-1c23-4a94-b50f-c4620e8254be
# Description              : 
# Issued                   : 2024-11-27T11:09:18.521710
# Modified                 : 2025-07-28T02:37:09.171704
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_tageswerte/download/ugz_ogd_air_d1_2024.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
