# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **6212fd20-e816-4828-a67f-90f057f25ddb@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Daten der Verkehrszählung zum motorisierten Individualverkehr (Stundenwerte), seit 2012**

# %% [markdown]
# ## Description
#
# Die hier verfügbaren Datensätze beinhalten die **täglich aktualisierten** Messwerte zum motorisierten Individualverkehr (MIV) in der Stadt Zürich, welche von den zahlreichen Zählstellen der Dienstabteilung Verkehr (DAV) gemessen wurden.
#
# Die Aktualisierung beinhaltet jeweils die Daten vom **Vortag**. Bis spätestens 07:00 Uhr morgens sind die neuesten Daten des Vortags verfügbar.
#
# Zu einer Zählstelle gehören mehrere Messstellen, welche wiederum Messungen mit sogenannten Detektoren vornehmen. In den vorliegenden Datensätzen sind die Messwerte pro Zählstelle enthalten. Für jede Zählstelle gibt es einen detaillierten PDF-Situationsplan in der Datei 'Zaehlstellen_Detail.zip', welcher u.a. die genaue Lage der Detektoren anzeigt.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/daten-der-verkehrszahlung-zum-motorisierten-individualverkehr-stundenwerte-seit-2012)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Dienstabteilung Verkehr, Sicherheitsdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['tabelle', 'motorrad', 'verkehrszaehlung', 'auto', 'stau', 'sachdaten', 'sasa', 'zeitreihe', 'verkehr']`
# - **Issued** `2020-03-13T00:00:00`
# - **Metadata_created** `2025-07-05T03:33:13.749034`
# - **Metadata_modified** `2025-07-23T03:13:12.851832`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`14` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:07:03.038170
# Modified                 : 2025-07-22T10:45:38.061970
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2012.csv')

# Distribution 1
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2021-01-01T05:57:10.630765
# Modified                 : 2025-07-22T10:48:00.846723
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2021.csv')

# Distribution 2
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2022-01-01T05:59:15.338190
# Modified                 : 2025-07-22T10:48:24.819280
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2022.csv')

# Distribution 3
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:31.775777
# Modified                 : 2025-07-22T10:46:49.062754
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2017.csv')

# Distribution 4
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:43.476235
# Modified                 : 2025-07-22T10:47:21.335787
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2019.csv')

# Distribution 5
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2024-01-01T07:16:55.636997
# Modified                 : 2025-07-22T10:49:07.762867
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2024.csv')

# Distribution 6
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:01.347642
# Modified                 : 2025-07-22T10:46:03.137109
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2014.csv')

# Distribution 7
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:07:14.149316
# Modified                 : 2025-07-22T10:46:18.445605
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2015.csv')

# Distribution 8
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:54.770310
# Modified                 : 2025-07-22T10:45:49.049433
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2013.csv')

# Distribution 9
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:17.169871
# Modified                 : 2025-07-22T10:47:04.017665
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2018.csv')

# Distribution 10
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2023-01-01T06:13:36.021797
# Modified                 : 2025-07-22T10:48:48.242892
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2023.csv')

# Distribution 11
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:08.651800
# Modified                 : 2025-07-22T10:46:33.817821
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2016.csv')

# Distribution 12
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2025-08-07T03:48:44.633518
# Modified                 : 2025-07-22T10:49:36.643330
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2025.csv')

# Distribution 13
# Package_id               : 87a48064-fb76-4d53-95f6-c18e31a5489b
# Description              : 
# Issued                   : 2020-11-03T12:06:29.910316
# Modified                 : 2025-07-22T10:47:39.035160
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2020.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
