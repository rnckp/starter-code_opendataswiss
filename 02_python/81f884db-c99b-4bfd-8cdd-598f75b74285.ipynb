# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **istdaten@oevch**

# %% [markdown]
# ## Dataset
# # **Ist-Daten**

# %% [markdown]
# ## Description
#
# Die Ist-Daten enthalten die effektiv gefahrenen Fahrten des letzten bzw. des entsprechenden Tages. Die Ist-Daten sind entweder effektive Ist-Daten oder die letzte Prognose, die das Kundeninformationssystem erhalten hat. Wenn keine Echtzeitinformationen vorhanden waren, so fehlt die entsprechende Fahrt.
#
# Ist-Daten Archiv: https://opentransportdata.swiss/de/ist-daten-archiv/

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/ist-daten-actual-data)<br>
# [Direct link by Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG) for dataset](https://opentransportdata.swiss/dataset/istdaten)

# %% [markdown]
# ## Metadata
# - **Publisher** `CUS`
# - **Organization.display_name.de** `Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG)`
# - **Organization.url** `https://www.opentransportdata.swiss`
# - **Maintainer** `Specialist office Open Data`
# - **Maintainer_email** `opendata@sbb.ch`
# - **Keywords.de** `['punktlichkeit', 'zug', 'proprietar', 'passagier', 'prognose', 'bus', 'daten', 'ist-daten', 'embag', 'verspatung']`
# - **Issued** `2016-12-01T12:00:00`
# - **Metadata_created** `2017-03-02T09:12:01.220199`
# - **Metadata_modified** `2024-11-01T02:35:45.788690`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`50` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-24T01:42:20.923345
# Modified                 : 2024-10-24T01:42:20.923345
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/f562f295-3216-45be-b947-39f1c586e0a7/download/2024-10-23_istdaten.csv')

# Distribution 1
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-14T00:52:17.125137
# Modified                 : 2024-09-14T00:52:17.125137
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/cf76ca30-29b1-401f-a620-cd4747200c39/download/2024-09-13_istdaten.csv')

# Distribution 2
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-06T00:52:08.926086
# Modified                 : 2024-10-06T00:52:08.926086
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/e235bc26-f5ec-472f-922c-46afe17b12b8/download/2024-10-05_istdaten.csv')

# Distribution 3
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-29T01:02:44.878380
# Modified                 : 2024-09-29T01:02:44.878380
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/6e5967b0-7a99-4cea-a5ab-2093ef6a90b1/download/2024-09-28_istdaten.csv')

# Distribution 4
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-17T01:22:22.021769
# Modified                 : 2024-10-17T01:22:22.021769
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/e89143c6-3b37-4325-b966-6d64436fbf28/download/2024-09-25_istdaten.csv')

# Distribution 40
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-30T00:51:28.005905
# Modified                 : 2024-09-30T00:51:28.005905
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/22eee696-a394-4ea6-9035-25d15b8b20f7/download/2024-09-29_istdaten.csv')

# Distribution 41
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-27T16:08:49.208907
# Modified                 : 2024-09-27T16:08:49.208907
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/49269a8c-b675-4531-904a-2fc918b5e99b/download/2024-09-26_istdaten.csv')

# Distribution 42
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-27T15:46:20.394503
# Modified                 : 2024-09-27T15:46:20.394503
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/7080b98c-d4d1-4194-a787-d0e528b10375/download/2024-09-15_istdaten.csv')

# Distribution 43
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-22T01:17:13.010523
# Modified                 : 2024-10-22T01:17:13.010523
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/55638af2-1d60-4a62-bfce-ed852d7a00a8/download/2024-10-21_istdaten.csv')

# Distribution 44
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-29T02:26:58.827991
# Modified                 : 2024-10-29T02:26:58.827991
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/6ee42645-1223-4cdd-a1c2-c22be52c6cf3/download/2024-10-28_istdaten.csv')

# Distribution 45
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-09-27T15:58:50.796665
# Modified                 : 2024-09-27T15:58:50.796665
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/c9900a59-6349-48dc-a6ad-918da72e0444/download/2024-09-21_istdaten.csv')

# Distribution 46
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-26T01:07:11.584512
# Modified                 : 2024-10-26T01:07:11.584512
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/3db98439-beae-4b04-9ad2-d662a2ac81c5/download/2024-10-25_istdaten.csv')

# Distribution 47
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-30T02:07:12.696486
# Modified                 : 2024-10-30T02:07:12.696486
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/e6c4a9cb-909b-4b85-bd3d-123b5ffcb3bb/download/2024-10-29_istdaten.csv')

# Distribution 48
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-31T01:52:07.784605
# Modified                 : 2024-10-31T01:52:07.784605
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/620b36ed-ea18-448a-b6b4-4f9002fbf571/download/2024-10-30_istdaten.csv')

# Distribution 49
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2024-10-15T00:57:27.769758
# Modified                 : 2024-10-15T00:57:27.769758
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/2e996e11-0a45-4805-bf7f-d27c679c9821/download/2024-10-14_istdaten.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@sbb.ch | Open Data Mobilität Schweiz
