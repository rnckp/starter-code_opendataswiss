# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **istdaten@oevch**

# %% [markdown]
# ## Dataset
# # **Ist-Daten**

# %% [markdown]
# ## Description
#
# Die Ist-Daten enthalten die effektiv gefahrenen Fahrten des letzten bzw. des entsprechenden Tages. Die Ist-Daten sind entweder effektive Ist-Daten oder die letzte Prognose, die das Kundeninformationssystem erhalten hat. Wenn keine Echtzeitinformationen vorhanden waren, so fehlt die entsprechende Fahrt.
#
# Ist-Daten Archiv: https://archive.opentransportdata.swiss/actual_data_archive.htm

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/ist-daten-actual-data)<br>
# [Direct link by Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG) for dataset](https://data.opentransportdata.swiss/dataset/istdaten)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `CUS`
# - **Organization.display_name.de** `Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG)`
# - **Organization.url** `https://www.opentransportdata.swiss`
# - **Maintainer** `Specialist office Open Data`
# - **Maintainer_email** `opendata@sbb.ch`
# - **Keywords.de** `['bus', 'punktlichkeit', 'ist-daten', 'passagier', 'proprietar', 'embag', 'prognose', 'verspatung', 'daten', 'zug']`
# - **Issued** `2016-12-01T12:00:00`
# - **Metadata_created** `2017-03-02T09:12:01.220199`
# - **Metadata_modified** `2025-07-26T01:39:51.969449`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`50` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-21T01:12:32.538135
# Modified                 : 2025-06-21T01:12:32.538135
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/f6a14d1d-0572-425a-aa7a-6c1de82cc081/download/2025-06-20_istdaten.csv')

# Distribution 1
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-08T01:26:54.761058
# Modified                 : 2025-06-08T01:26:54.761058
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/9f9edd47-db5c-4ece-ba46-41fe7f5212c2/download/2025-06-07_istdaten.csv')

# Distribution 2
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07-15T01:32:34.132713
# Modified                 : 2025-07-15T01:32:34.132713
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/600e3102-a72c-4c2e-9b21-e02d0ac761ac/download/2025-07-14_istdaten.csv')

# Distribution 3
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-13T01:03:47.460093
# Modified                 : 2025-06-13T01:03:47.460093
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/7bc24d5e-fac7-470f-821b-37b1d0c42f37/download/2025-06-12_istdaten.csv')

# Distribution 4
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-30T01:06:38.509128
# Modified                 : 2025-06-30T01:06:38.509128
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/b9fe49a6-bdb1-44f6-a7a4-30733777f887/download/2025-06-29_istdaten.csv')

# Distribution 39
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-16T01:42:34.465478
# Modified                 : 2025-06-16T01:42:34.465478
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/7b786010-04de-45f6-b95e-aba470cd8d46/download/2025-06-15_istdaten.csv')

# Distribution 40
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-23T01:51:32.512758
# Modified                 : 2025-06-23T01:51:32.512758
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/42582050-3297-45ba-9353-194c763bef6a/download/2025-06-22_istdaten.csv')

# Distribution 41
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-15T01:51:52.416631
# Modified                 : 2025-06-15T01:51:52.416631
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/5829b0c1-c53e-4099-b75d-882a47537ef8/download/2025-06-14_istdaten.csv')

# Distribution 42
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-20T01:32:28.708372
# Modified                 : 2025-06-20T01:32:28.708372
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/4eb5d98b-8090-49be-bc1a-cca56917607b/download/2025-06-19_istdaten.csv')

# Distribution 43
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-09T01:10:18.134820
# Modified                 : 2025-06-09T01:10:18.134820
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/9f4f5e22-af8f-4ccd-800b-844bcdb2a424/download/2025-06-08_istdaten.csv')

# Distribution 44
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07-21T01:17:20.605031
# Modified                 : 2025-07-21T01:17:20.605031
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/2cd3d108-2fa7-4581-bc65-0f4d5f375620/download/2025-07-20_istdaten.csv')

# Distribution 45
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-12T01:26:48.300103
# Modified                 : 2025-06-12T01:26:48.300103
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/ba28e2f1-d639-4c49-bbb9-8931a7e298b4/download/2025-06-11_istdaten.csv')

# Distribution 46
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07-19T01:42:14.111638
# Modified                 : 2025-07-19T01:42:14.111638
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/ed791793-a5d9-4a2b-9477-8550dd83231f/download/2025-07-18_istdaten.csv')

# Distribution 47
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07-01T02:03:18.003786
# Modified                 : 2025-07-01T02:03:18.003786
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/28e0b14c-c4ac-4947-8206-ec3da969ec1c/download/2025-06-30_istdaten.csv')

# Distribution 48
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-07-22T02:07:29.491107
# Modified                 : 2025-07-22T02:07:29.491107
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/1a3accf7-c47c-44d5-afc8-0bfe16b28465/download/2025-07-21_istdaten.csv')

# Distribution 49
# Package_id               : 81f884db-c99b-4bfd-8cdd-598f75b74285
# Description              : The actual service provided is displayed. The final forecast is used where no actual data are available.
# Issued                   : 2025-06-14T02:02:50.166324
# Modified                 : 2025-06-14T02:02:50.166324
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/0edc74a3-ad4d-486e-8657-f8f3b34a0979/resource/a9b3bc60-a0a2-4b90-bfdf-ed79f24075c3/download/2025-06-13_istdaten.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@sbb.ch | Open Data Mobilität Schweiz
