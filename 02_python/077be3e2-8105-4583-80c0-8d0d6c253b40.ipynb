# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **transit@eidgenoessische_zollverwaltung_ezv**

# %% [markdown]
# ## Dataset
# # **Waren: Aussenhandel - Transitdaten durch die Schweiz**

# %% [markdown]
# ## Description
#
# Die Transitstatistik erfasst sämtliche ausländischen Waren, welche die Schweiz beim Transport durchqueren.

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/waren-aussenhandel-transitdaten-durch-die-schweiz)<br>
# [Direct link by Bundesamt für Zoll und Grenzsicherheit BAZG for dataset]()

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Bundesamt für Zoll und Grenzsicherheit BAZG`
# - **Organization.url** `https://www.bazg.admin.ch/bazg/de/home.html`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['aussenhandel', 'bazg', 'transit']`
# - **Issued** `2025-02-20T00:00:00`
# - **Metadata_created** `2025-12-24T14:30:12.033279`
# - **Metadata_modified** `2026-01-28T12:53:55.896066`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`6` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              :  (ZIP containing primarily CSV files) (ZIP containing primarily CSV files)
# Issued                   : 2025-02-20T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/UI2WORV-xmOK/TRANSIT_DATEN_2023.zip')

# Distribution 1
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              : In der Transitstatistik werden die Waren auf Basis von einer für die Schweiz spezifischen Nomenklatur klassifiziert. Die in der Zollanmeldung verfügbare Warenbeschreibung ermöglicht diese Klassifizierung.
# Issued                   : 2024-09-26T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/6XF8LXV0SqEW/OGD_WARENGRUPPEN_TRANSIT.csv')

# Distribution 2
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              :  Der Zoll verfügt über Dienststellen in der ganzen Schweiz. Im Dienststellenverzeichnis finden Sie alle Dienststellen mit den jeweiligen Informationen.
# Issued                   : 2024-09-26T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/NXxP5kG5RWZn/OGD_ZOLLSTELLEN_TRANSIT.csv')

# Distribution 3
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              :  (ZIP containing primarily CSV files) (ZIP containing primarily CSV files) Durch die Umstellung auf das neue Warenverkehrssystem (Passar), das eine präzisere Datenerfassung gewährleistet, können bei detaillierten Datenauswertungen der Strasse im 2024 Veränderungen auftreten (z.B. Transportierte Ware nach inländischen/ausländischen Fahrzeugen).
# Issued                   : 2025-09-30T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/cTJbViGm7ty8/TRANSIT_DATEN_2024.zip')

# Distribution 4
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              : Beim Transit wird für alle Transporte dasjenige Verkehrsmittel aufgeführt, mit welchem die längste Wegstrecke innerhalb der Schweiz zurückgelegt wurde. Der Transit kann entweder auf der Schiene, Strasse oder per Pipeline erfolgen. Nicht erfasst werden Transite im Schiffs- und Luftverkehr.
# Issued                   : 2025-02-20T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/Qo78y-AJTGj8/OGD_VERKEHRSTRAEGER_TRANSIT.csv')

# Distribution 5
# Package_id               : 077be3e2-8105-4583-80c0-8d0d6c253b40
# Description              : Das Länderverzeichnis der Aussenhandelsstatistik ist nur für statistische Zwecke bestimmt. Die verwendeten Bezeichnungen sowie der Umstand, ob einzelne Länder bzw. Regionen erwähnt sind oder nicht, kommt nicht einer Stellungnahme des BAZG oder einer anderen schweizerischen Behörde über den juristischen Status der Länder gleich
# Issued                   : 2024-09-26T00:00:00
# Modified                 : None
# Rights                   : https://opendata.swiss/terms-of-use#terms_by_ask

df = get_dataset('https://www.bazg.admin.ch/dam/de/sd-web/gPZ-d32XZAu5/OGD_LAENDER_TRANSIT.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: stat@bazg.admin.ch | Bundesamt für Zoll und Grenzsicherheit
