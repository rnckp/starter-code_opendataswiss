# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **f85c7171-2635-43ba-81f5-6b01b56500d2@envidat**

# %% [markdown]
# ## Dataset
# # **Advancing sustainable LED solutions to mitigate light-pollution impacts on arthropods**

# %% [markdown]
# ## Description

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/advancing-sustainable-led-solutions-to-mitigate-light-pollution-impacts-on-arthropods)<br>
# [Direct link by EnviDat: das Umwelt-Datenportal for dataset](https://www.envidat.ch/#/metadata/alan---nature-sustainability)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `EnviDat`
# - **Organization.display_name.de** `EnviDat: das Umwelt-Datenportal`
# - **Organization.url** `https://www.envidat.ch/`
# - **Maintainer** `EnviDat Support`
# - **Maintainer_email** `envidat@wsl.ch`
# - **Keywords.de** `[]`
# - **Issued** `2024-12-09T15:39:34+00:00`
# - **Metadata_created** `2024-12-14T04:32:49.061556`
# - **Metadata_modified** `2025-06-03T09:33:58.945552`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`6` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:41:47+00:00
# Modified                 : 2024-12-09T16:43:03+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/aa8b6e52-c154-482c-a4db-2a9ff2ceaff2')

# Distribution 1
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:43:10+00:00
# Modified                 : 2024-12-09T16:44:24+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/388d1352-f4ab-4c80-9439-b47ff1b2d84a')

# Distribution 2
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:46:00+00:00
# Modified                 : 2024-12-09T16:46:15+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/7aa3a91d-3ed9-477c-aa15-68c42f50392b')

# Distribution 3
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:45:23+00:00
# Modified                 : 2024-12-09T16:45:54+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/92df1cc5-e8f7-4ed8-98b6-8f512edd3504')

# Distribution 4
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:40:58+00:00
# Modified                 : 2024-12-09T16:41:38+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/3aecf663-0494-4d8d-9a9b-70ee70584c33')

# Distribution 5
# Package_id               : fd8a64c5-d362-4874-83ae-5e9da23a9019
# Description              : 
# Issued                   : 2024-12-09T15:46:22+00:00
# Modified                 : 2024-12-09T16:46:37+00:00
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://www.envidat.ch/dataset/alan---nature-sustainability/resource/352f7a23-41a2-4160-b5da-000ca56511bb')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: nicola.vkoppenhagen@wsl.ch | Nicola Vkoppenhagen
