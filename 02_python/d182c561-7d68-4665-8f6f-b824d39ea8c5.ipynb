# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **3869188c-50dd-418b-826e-4ce2191d0c71@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten der VBZ im SOLL-IST-Vergleich**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die aktuellen Daten des laufenden Jahres ab dem **1. Januar 2023 **. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-der-vbz-im-soll-ist-vergleich1)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd)

# %% [markdown]
# ## Metadata
# - **Publisher** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['hackzurich', 'tabelle', 'bus', 'offentlicher-verkehr', 'verspatung', 'vbz', 'sachdaten', 'tram', 'punktlichkeit']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2023-01-21T01:15:13.026657`
# - **Metadata_modified** `2024-08-02T03:12:53.177388`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`32` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-09-07T20:06:42.077322
# Modified                 : 2024-01-08T13:21:02.161075
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230625_20230701.csv')

# Distribution 1
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-08-13T20:08:29.790633
# Modified                 : 2024-01-08T13:22:04.438371
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230723_20230729.csv')

# Distribution 2
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-07-30T20:08:13.767938
# Modified                 : 2024-01-08T13:21:49.640235
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230716_20230722.csv')

# Distribution 3
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-07-05T19:43:00.762564
# Modified                 : 2024-01-08T13:18:09.342414
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230423_20230429.csv')

# Distribution 4
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-01-20T17:22:40.081741
# Modified                 : 2024-01-08T13:14:07.674270
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230101_20230107.csv')

# Distribution 5
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-03-26T20:04:59.890989
# Modified                 : 2024-01-08T13:16:42.772023
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230312_20230318.csv')

# Distribution 6
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-07-05T19:42:36.666187
# Modified                 : 2024-01-08T13:17:10.970491
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20230326_20230401.csv')

# Distribution 7
# Package_id               : d182c561-7d68-4665-8f6f-b824d39ea8c5
# Description              : 
# Issued                   : 2023-07-23T20:04:14.758063
# Modified                 : 2024-01-08T13:21:34.579316
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd/download/Fahrzeiten_SOLL_IST_20