# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **transit@eidgenoessische_zollverwaltung_ezv**

# %% [markdown]
# ## Dataset
# # **Provisorische Transitdaten durch die Schweiz 2023**

# %% [markdown]
# ## Description
#
# Die Transitstatistik erfasst sämtliche ausländischen Waren, welche die Schweiz beim Transport durchqueren. Das Dataset enthält provisorische Daten, da die Passar-Daten noch nicht vorhanden sind.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/transit_data)<br>
# [Direct link by Bundesamt für Zoll und Grenzsicherheit BAZG for dataset](https://www.bazg.admin.ch/bazg/de/home/themen/schweizerische-aussenhandelsstatistik/daten/verkehrmittel.html)

# %% [markdown]
# ## Metadata
# - **Publisher** `BAZG - Statistische Informationen`
# - **Organization.display_name.de** `Bundesamt für Zoll und Grenzsicherheit BAZG`
# - **Organization.url** `https://www.bazg.admin.ch/bazg/de/home.html`
# - **Maintainer** `BAZG - Statistische Informationen`
# - **Maintainer_email** `stat@bazg.admin.ch`
# - **Keywords.de** `['exporte', 'importe']`
# - **Issued** `2024-09-26T00:00:00`
# - **Metadata_created** `2024-09-23T07:26:14.220589`
# - **Metadata_modified** `2024-09-24T10:29:04.576940`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : f5bacd9d-7c99-4b82-bdec-ddd19bc9622b
# Description              :  Der Zoll verfügt über Dienststellen in der ganzen Schweiz. Im Dienststellenverzeichnis finden Sie alle Dienststellen mit den jeweiligen Informationen.
# Issued                   : 2024-09-26T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.bazg.admin.ch/bazg/de/home/themen/schweizerische-aussenhandelsstatistik/daten/verkehrmittel/OGD_Zollstellen.csv')

# Distribution 1
# Package_id               : f5bacd9d-7c99-4b82-bdec-ddd19bc9622b
# Description              : Beim Transit wird für alle Transporte dasjenige Verkehrsmittel aufgeführt, mit welchem die längste Wegstrecke innerhalb der Schweiz zurückgelegt wurde. Der Transit kann entweder auf der Schiene, Strasse oder per Pipeline erfolgen. Nicht erfasst werden Transite im Schiffs- und Luftverkehr.
# Issued                   : 2024-09-26T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.bazg.admin.ch/bazg/de/home/themen/schweizerische-aussenhandelsstatistik/daten/verkehrmittel/OGD_VERKEHRSTRAEGER_TRANSIT.csv')

# Distribution 2
# Package_id               : f5bacd9d-7c99-4b82-bdec-ddd19bc9622b
# Description              : Die Aussenhandelsstatistik erhebt die Daten auf der Basis der Warenanmeldungen, die gemäss dem schweizerischen Zolltarif (Tares) erfolgen. Somit gibt der Zolltarif die Struktur der Aussenhandelsstatistik vor, wobei die einzelnen Tarifnummern je nach Fragestellung zu unterschiedlichen Warengruppen (= Nomenklaturen) zusammengefasst werden. 
# Issued                   : 2024-09-26T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.bazg.admin.ch/bazg/de/home/themen/schweizerische-aussenhandelsstatistik/daten/verkehrmittel/OGD_WARENGRUPPEN_TRANSIT.csv')

# Distribution 3
# Package_id               : f5bacd9d-7c99-4b82-bdec-ddd19bc9622b
# Description              : Das Länderverzeichnis der Aussenhandelsstatistik ist nur für statistische Zwecke bestimmt. Die verwendeten Bezeichnungen sowie der Umstand, ob einzelne Länder bzw. Regionen erwähnt sind oder nicht, kommt nicht einer Stellungnahme des BAZG oder einer anderen schweizerischen Behörde über den juristischen Status der Länder gleich
# Issued                   : 2024-09-26T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://www.bazg.admin.ch/dam/bazg/de/dokumente/abgaben/aussenhandelstatistik/diffusion/Daten/Waren/OGD_LAND.csv.download.csv/OGD_LAND.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: stat@bazg.admin.ch | BAZG - Statistische Informationen
