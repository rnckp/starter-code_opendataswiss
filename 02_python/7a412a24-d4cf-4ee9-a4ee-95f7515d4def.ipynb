# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for dataset with identifier* **f25fd2ed-2912-488d-8c8c-284e1fdc83fa@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten 2022 der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die Daten des Jahres **2022**. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-2022-der-vbz-im-soll-ist-vergleich-nachfuhrung-eingestellt1)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['bus', 'hackzurich', 'offentlicher-verkehr', 'punktlichkeit', 'sachdaten', 'tabelle', 'tram', 'vbz', 'verspatung']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2025-11-06T02:42:28.353446`
# - **Metadata_modified** `2026-01-09T01:24:33.849409`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`54` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:58:01.393491
# Modified                 : 2026-07-01T20:34:12.558520
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Haltestelle.csv')

# Distribution 1
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:57:59.642870
# Modified                 : 2026-07-01T20:34:10.691872
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Haltepunkt.csv')

# Distribution 2
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:57:49.712571
# Modified                 : 2026-07-01T20:34:00.596975
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221225_20221231.csv')

# Distribution 3
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:57:38.138943
# Modified                 : 2026-07-01T20:33:49.652431
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221218_20221224.csv')

# Distribution 4
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:57:26.515942
# Modified                 : 2026-07-01T20:33:39.728860
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221211_20221217.csv')

# Distribution 5
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220605_20220611.csv')

# Distribution 32
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:46:28.229641
# Modified                 : 2026-07-01T20:23:09.834140
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220529_20220604.csv')

# Distribution 33
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:46:18.788224
# Modified                 : 2026-07-01T20:23:00.017297
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220522_20220528.csv')

# Distribution 34
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:46:07.519224
# Modified                 : 2026-07-01T20:20:59.429476
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220515_20220521.csv')

# Distribution 35
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:45:50.874247
# Modified                 : 2026-07-01T20:20:49.188729
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220508_20220514.csv')

# Distribution 36
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:45:28.205770
# Modified                 : 2026-07-01T20:20:35.842601
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220501_20220507.csv')

# Distribution 37
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:43:23.760234
# Modified                 : 2026-07-01T20:20:23.811954
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220424_20220430.csv')

# Distribution 38
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:43:12.879334
# Modified                 : 2026-07-01T20:20:14.007311
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220417_20220423.csv')

# Distribution 39
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:43:01.370522
# Modified                 : 2026-07-01T20:20:02.750515
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220410_20220416.csv')

# Distribution 40
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:42:52.662146
# Modified                 : 2026-07-01T20:18:07.807770
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220403_20220409.csv')

# Distribution 41
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:42:39.133536
# Modified                 : 2026-07-01T20:17:57.683192
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220327_20220402.csv')

# Distribution 42
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:42:29.592414
# Modified                 : 2026-07-01T20:17:47.707107
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220320_20220326.csv')

# Distribution 43
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:42:12.855417
# Modified                 : 2026-07-01T20:17:34.638857
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220313_20220319.csv')

# Distribution 44
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:42:00.437724
# Modified                 : 2026-07-01T20:17:16.644888
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220306_20220312.csv')

# Distribution 45
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:41:41.806619
# Modified                 : 2026-07-01T20:17:02.443437
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220227_20220305.csv')

# Distribution 46
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:39:41.022853
# Modified                 : 2026-07-01T20:14:50.000509
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220220_20220226.csv')

# Distribution 47
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:39:30.769657
# Modified                 : 2026-07-01T20:14:37.654324
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220213_20220219.csv')

# Distribution 48
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:39:19.437315
# Modified                 : 2026-07-01T20:14:24.232296
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220206_20220212.csv')

# Distribution 49
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:39:09.053999
# Modified                 : 2026-07-01T20:14:10.871998
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220130_20220205.csv')

# Distribution 50
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:38:56.880441
# Modified                 : 2026-07-01T20:13:57.281748
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220123_20220129.csv')

# Distribution 51
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:38:47.425743
# Modified                 : 2026-07-01T20:13:44.069474
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220116_20220122.csv')

# Distribution 52
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:38:37.954420
# Modified                 : 2026-07-01T20:13:30.687793
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220109_20220115.csv')

# Distribution 53
# Package_id               : 7a412a24-d4cf-4ee9-a4ee-95f7515d4def
# Description              : 
# Issued                   : 2025-05-11T13:38:25.659211
# Modified                 : 2026-07-01T20:13:17.882566
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220102_20220108.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
