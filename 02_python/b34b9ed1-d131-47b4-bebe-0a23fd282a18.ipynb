# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **f92dc576-2555-415b-b239-c7c2dc8aa2f9@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Beschäftigte nach Sektor, Geschlecht und Beschäftigungsgrad, Vollzeitäquivalente, seit Q2 2003**

# %% [markdown]
# ## Description
#
#
# Diese Daten beinhalten aggreggierte Beschäftigtenzahlen in der Stadt Zürich und den nächsthöheren Ebenen. Die Daten für die Stadt Zürich werden nach diversen Merkmalen unterteilt (Sektor, Geschlecht, Beschäftigungsgrad). Ausserdem werden für die Stadt Zürich auch noch Vollzeitäquivalente ausgewiesen.
#
# Bitte beachten Sie für das korrekte Verständnis zu den Daten die unten aufgeführten weiteren Erläuterungen in der Rubrik **«Bemerkungen»**.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/beschaftigte-nach-sektor-geschlecht-und-beschaftigungsgrad-vollzeitaquivalente-seit-q2-2003)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002)

# %% [markdown]
# ## Metadata
# - **Publisher** `Beschäftigtenstatistik, Bundesamt für Statistik`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['zeitreihe', 'vollzeitaequivalente', 'sachdaten', 'wirtschaftssektor', 'beschaeftigte', 'sasa', 'tabelle']`
# - **Issued** `2021-06-20T00:00:00`
# - **Metadata_created** `2021-06-23T02:27:41.113816`
# - **Metadata_modified** `2023-01-16T00:49:43.071978`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : b34b9ed1-d131-47b4-bebe-0a23fd282a18
# Description              : 
# Issued                   : 2021-06-22T00:00:00
# Modified                 : 2023-01-16T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002/download/WIR400OD4002.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
