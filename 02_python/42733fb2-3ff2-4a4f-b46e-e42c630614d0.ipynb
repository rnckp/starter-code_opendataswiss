# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for dataset with identifier* **5a19ac1f-e938-4b10-a1f8-ae409451e977@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten 2020 der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die Daten des Jahres 2020. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-2020-der-vbz-im-soll-ist-vergleich-nachfuhrung-eingestellt)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['bus', 'hackzurich', 'offentlicher-verkehr', 'punktlichkeit', 'sachdaten', 'tabelle', 'tram', 'vbz', 'verspatung']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2025-11-06T02:44:27.153389`
# - **Metadata_modified** `2025-12-19T01:54:23.645327`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`54` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:02:27.126712
# Modified                 : 2025-05-11T17:02:27.074935
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200105_20200111.csv')

# Distribution 1
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:02:36.168653
# Modified                 : 2025-05-11T17:02:36.090663
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:14:11.851112
# Modified                 : 2025-05-11T17:14:11.736915
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200830_20200905.csv')

# Distribution 35
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:14:23.781969
# Modified                 : 2025-05-11T17:14:22.673330
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200906_20200912.csv')

# Distribution 36
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:16:35.702781
# Modified                 : 2025-05-11T17:16:35.554935
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200913_20200919.csv')

# Distribution 37
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:16:49.997405
# Modified                 : 2025-05-11T17:16:49.858612
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200920_20200926.csv')

# Distribution 38
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:00.679776
# Modified                 : 2025-05-11T17:17:00.151287
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20200927_20201003.csv')

# Distribution 39
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:10.749212
# Modified                 : 2025-05-11T17:17:10.604214
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201004_20201010.csv')

# Distribution 40
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:22.299968
# Modified                 : 2025-05-11T17:17:22.160672
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201011_20201017.csv')

# Distribution 41
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:32.873697
# Modified                 : 2025-05-11T17:17:32.744720
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201018_20201024.csv')

# Distribution 42
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:43.282069
# Modified                 : 2025-05-11T17:17:43.155038
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201025_20201031.csv')

# Distribution 43
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:17:52.578883
# Modified                 : 2025-05-11T17:17:52.417213
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201101_20201107.csv')

# Distribution 44
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:19:57.133227
# Modified                 : 2025-05-11T17:19:56.998179
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201108_20201114.csv')

# Distribution 45
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:20:06.996361
# Modified                 : 2025-05-11T17:20:06.859247
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201115_20201121.csv')

# Distribution 46
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:20:17.925503
# Modified                 : 2025-05-11T17:20:17.396155
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201122_20201128.csv')

# Distribution 47
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:20:30.730932
# Modified                 : 2025-05-11T17:20:30.586517
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201129_20201205.csv')

# Distribution 48
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:20:42.389533
# Modified                 : 2025-05-11T17:20:42.202221
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201206_20201212.csv')

# Distribution 49
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:20:53.664288
# Modified                 : 2025-05-11T17:20:53.401097
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201213_20201219.csv')

# Distribution 50
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:21:06.623914
# Modified                 : 2025-05-11T17:21:06.480894
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201220_20201226.csv')

# Distribution 51
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:21:16.261935
# Modified                 : 2025-05-11T17:21:16.112915
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Fahrzeiten_SOLL_IST_20201227_20210102.csv')

# Distribution 52
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:21:25.691511
# Modified                 : 2025-05-11T17:21:25.137234
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Haltepunkt.csv')

# Distribution 53
# Package_id               : 42733fb2-3ff2-4a4f-b46e-e42c630614d0
# Description              : 
# Issued                   : 2025-05-11T17:21:27.469617
# Modified                 : 2025-05-11T17:21:27.317483
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2020/download/Haltestelle.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
