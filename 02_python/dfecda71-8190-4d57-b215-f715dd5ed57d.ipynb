# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **12ef82b6-f31e-4989-a74a-895d32bd4e0d@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Täglich aktualisierte Meteodaten, seit 1992**

# %% [markdown]
# ## Description
#
#
# Der Datensatz umfasst **Tageswerte** **ab 1992 bis zum aktuellen Vortag** aufgeteilt in Jahresdateien. Darin enthalten sind die Stationen Stampfenbachstrasse, Schimmelstrasse und Rosengartenstrasse. Gemessen wird der Luftdruck (p), die Niederschlagsdauer (RainDur), die Globalstrahlung (StrGlo), die Temperatur (T) und die relative Luftfeuchtigkeit (Hr). Die Winddaten werden zur Zeit nicht auf Tageswerte gemittelt, sind aber im Datensatz 'Stündlich aktualisierte Meteodaten, seit 1988' als Stundenwerte verfügbar.
#
# Die Tageswerte des laufenden Jahres werden jeweils 30 Minuten nach Mitternacht (UTC+1) aktualisiert.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/taglich-aktualisierte-meteodaten-seit-1992)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte)

# %% [markdown]
# ## Metadata
# - **Publisher** `Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['luft', 'sachdaten', 'lufttemperatur', 'wind', 'feuchte', 'regen', 'wv', 'niederschlag', 'umweltdaten', 'messwerte', 'global-strahlung', 'hr', 'regendauer', 'luftdruck', 'p_', 'zeitreihe', 'meteo', 'wd', 'wetter', 'luftfeuchte', 'echtzeit', 't_', 'hitze', 'kalte', 'windgeschwindigkeit', 'temperatur', 'tabelle', 'windrichtung']`
# - **Issued** `nan`
# - **Metadata_created** `2024-11-28T02:49:35.069347`
# - **Metadata_modified** `2025-01-04T03:45:00.616564`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`34` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:22.445727
# Modified                 : 2025-04-01T01:44:23.148548
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2024.csv')

# Distribution 1
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:01.140777
# Modified                 : 2025-04-01T01:43:15.210059
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2005.csv')

# Distribution 2
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:58.873998
# Modified                 : 2025-04-01T01:43:07.231768
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2003.csv')

# Distribution 3
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:09.568761
# Modified                 : 2025-04-01T01:43:43.926410
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2013.csv')

# Distribution 4
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:05.468191
# Modified                 : 2025-04-01T01:43:30.710251
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2009.csv')

# Distribution 5
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:56.158829
# Modified                 : 2025-04-01T01:42:51.111589
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2000.csv')

# Distribution 6
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:57.937999
# Modified                 : 2025-04-01T01:43:03.512737
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2002.csv')

# Distribution 7
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:52.484907
# Modified                 : 2025-04-01T01:42:40.012664
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1997.csv')

# Distribution 8
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:49.890256
# Modified                 : 2025-04-01T01:42:29.005711
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1994.csv')

# Distribution 9
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:57.012844
# Modified                 : 2025-04-01T01:42:55.345672
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2001.csv')

# Distribution 10
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2025-01-01T23:44:22.909211
# Modified                 : 2025-04-01T01:44:27.140901
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2025.csv')

# Distribution 11
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:50.651453
# Modified                 : 2025-04-01T01:42:32.506918
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1995.csv')

# Distribution 12
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:03.331194
# Modified                 : 2025-04-01T01:43:23.247405
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2007.csv')

# Distribution 13
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:59.850802
# Modified                 : 2025-04-01T01:43:10.940747
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2004.csv')

# Distribution 14
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:12.880697
# Modified                 : 2025-04-01T01:43:54.540668
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2016.csv')

# Distribution 15
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:06.382302
# Modified                 : 2025-04-01T01:43:33.823628
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2010.csv')

# Distribution 16
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:21.412242
# Modified                 : 2025-04-01T01:44:19.827791
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2023.csv')

# Distribution 17
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:19.007572
# Modified                 : 2025-04-01T01:44:12.139193
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2021.csv')

# Distribution 18
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:51.642623
# Modified                 : 2025-04-01T01:42:36.312932
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1996.csv')

# Distribution 19
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:17.759302
# Modified                 : 2025-04-01T01:44:08.349769
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2020.csv')

# Distribution 20
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:47.724797
# Modified                 : 2025-04-01T01:42:22.123807
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1992.csv')

# Distribution 21
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:11.747337
# Modified                 : 2025-04-01T01:43:50.906047
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2015.csv')

# Distribution 22
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:04.437043
# Modified                 : 2025-04-01T01:43:26.524586
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2008.csv')

# Distribution 23
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:07.656563
# Modified                 : 2025-04-01T01:43:37.123516
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2011.csv')

# Distribution 24
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:53.318712
# Modified                 : 2025-04-01T01:42:44.223860
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1998.csv')

# Distribution 25
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:48.682988
# Modified                 : 2025-04-01T01:42:25.221559
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1993.csv')

# Distribution 26
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:08.642617
# Modified                 : 2025-04-01T01:43:40.716856
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2012.csv')

# Distribution 27
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:02.049301
# Modified                 : 2025-04-01T01:43:19.217885
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2006.csv')

# Distribution 28
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:12:55.297361
# Modified                 : 2025-04-01T01:42:47.618800
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_1999.csv')

# Distribution 29
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:16.701111
# Modified                 : 2025-04-01T01:44:05.246141
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2019.csv')

# Distribution 30
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:20.221121
# Modified                 : 2025-04-01T01:44:15.639566
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2022.csv')

# Distribution 31
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:15.185046
# Modified                 : 2025-04-01T01:44:02.046933
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2018.csv')

# Distribution 32
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:10.695118
# Modified                 : 2025-04-01T01:43:47.525024
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2014.csv')

# Distribution 33
# Package_id               : dfecda71-8190-4d57-b215-f715dd5ed57d
# Description              : 
# Issued                   : 2024-11-27T11:13:13.989677
# Modified                 : 2025-04-01T01:43:58.211426
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_meteodaten_tagesmittelwerte/download/ugz_ogd_meteo_d1_2017.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
