# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **f7152403-42ef-4267-b05e-5077e0fdc991@bundesamt-fur-meteorologie-und-klimatologie-meteoschweiz**

# %% [markdown]
# ## Dataset
# # **Klimaszenarien CH2025 pro Station - DAILY-LOCAL**

# %% [markdown]
# ## Description
#
# Die verfügbaren Datensätze der Schweizer Klimaszenarien CH2025 umfassen tägliche Zeitreihen mehrerer meteorologischer Grössen an Stationen (DAILY-LOCAL) und auf einem hochaufgelösten 1 km Gitter (DAILY-GRIDDED). Diese grossen Datensätze sind in erster Linie für die Weiterverarbeitung durch Computermodelle geeignet.

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/klimaszenarien-ch2025-pro-station-daily-local)<br>
# [Direct link by Bundesamt für Meteorologie und Klimatologie MeteoSchweiz for dataset](https://www.meteoschweiz.admin.ch/service-und-publikationen/service/open-data.html)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Bundesamt für Meteorologie und Klimatologie MeteoSchweiz`
# - **Organization.url** `https://www.meteoschweiz.admin.ch`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['atmospharische-bedingungen', 'meteorologisch-geografische-kennwerte', 'niederschlag', 'klima', 'meteorologie', 'sonnenscheindauer', 'druck', 'luftfeuchtigkeit', 'temperatur', 'klimatologie', 'wind', 'luft-atmosphare', 'strahlung', 'klimaanderung', 'bgdi-bundesgeodaten-infrastruktur', 'opendata']`
# - **Issued** `2025-11-01T00:00:00`
# - **Metadata_created** `2026-01-27T00:22:26.488101`
# - **Metadata_modified** `2026-01-27T00:22:26.488107`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`4` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : c643b746-0402-4f1e-b9bb-a75e86e6460b
# Description              : Alle Parameter haben eine eindeutige Kennung, die von der zeitlichen Auflösung abhängig ist. Diese Ressource enthält eine Liste aller Parameterkennungen mit Erläuterung, Zeitintervall, Dezimalstellen, Datentyp und Masseinheit.
# Issued                   : 2025-11-01T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://rgw.cscs.ch/mchogd:cscs.meteoswiss.ogd.climate/ogd-climate-scenarios-ch2025/ogd-climate-scenarios-ch2025_meta_parameters.csv')

# Distribution 1
# Package_id               : c643b746-0402-4f1e-b9bb-a75e86e6460b
# Description              : Alle Stationen haben eine aus drei Buchstaben bestehende Kennung (z.B. "BER" für "Bern/Zollikofen" oder "LUG" für "Lugano"). Diese Ressource enthält eine Liste aller Stationskennungen mit Namen, Kanton, Wigos ID, Stationstyp, Höhe, Koordinaten, Ausrichtung und URL der Stationsdetailseiten.
# Issued                   : 2025-11-01T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://rgw.cscs.ch/mchogd:cscs.meteoswiss.ogd.climate/ogd-climate-scenarios-ch2025/ogd-climate-scenarios-ch2025_meta_stations.csv')

# Distribution 2
# Package_id               : c643b746-0402-4f1e-b9bb-a75e86e6460b
# Description              : 
# Issued                   : 2025-11-01T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/api/stac/v1/collections/ch.meteoschweiz.ogd-climate-scenarios-ch2025')

# Distribution 3
# Package_id               : c643b746-0402-4f1e-b9bb-a75e86e6460b
# Description              : 
# Issued                   : 2025-11-01T00:00:00
# Modified                 : 
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.geo.admin.ch/browser/index.html#/collections/ch.meteoschweiz.ogd-climate-scenarios-ch2025')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata.en@meteoswiss.ch | opendata.en@meteoswiss.ch
