# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **11027919@bundesamt-fur-statistik-bfs**

# %% [markdown]
# ## Dataset
# # **Daten der Eidgenössischen Volkszählungen ab 1850 nach Gemeinden (CSV-Datensatz)**

# %% [markdown]
# ## Description
#
# Vorsicht: Verwenden Sie für das Öffnen des CSV-Datensatzes nicht Excel, da dieser mehr als 1,25 Millionen Zeilen enthält. Excel wird eine Fehlermeldung anzeigen und darauf hinweisen, dass der Datensatz nicht vollständig geladen wurde. Erläuterungen zu den Daten und zu den Erhebungen finden Sie im Excel-Datensatz weiter unten auf dieser Website.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/daten-der-eidgenossischen-volkszahlungen-ab-1850-nach-gemeinden-csv-datensatz)<br>
# [Direct link by Bundesamt für Statistik BFS for dataset](https://www.bfs.admin.ch/asset/de/su-d-01.01-vz1850-ge-01)

# %% [markdown]
# ## Metadata
# - **Publisher** `BFS/OFS`
# - **Organization.display_name.de** `Bundesamt für Statistik BFS`
# - **Organization.url** `https://www.bfs.admin.ch`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['tabelle', 'eidgenossische-volkszahlung--2000', 'vollerhebung', 'bevolkerung', 'registerauswertung', 'statistik-der-bevolkerung-und-der-haushalte', 'stichprobenerhebung', 'strukturerhebung']`
# - **Issued** `2019-11-29T00:00:00`
# - **Metadata_created** `2022-05-11T13:40:27.837835`
# - **Metadata_modified** `2023-01-16T10:17:51.856766`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`2` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 1e326398-1a55-4b34-9850-c4bc4c248894
# Description              : 
# Issued                   : 2019-11-29T00:00:00
# Modified                 : 2021-10-21T00:00:00
# Rights                   : NonCommercialAllowed-CommercialWithPermission-ReferenceRequired

df = get_dataset('https://www.bfs.admin.ch/bfsstatic/dam/assets/11047857/master')

# Distribution 1
# Package_id               : 1e326398-1a55-4b34-9850-c4bc4c248894
# Description              : Vorsicht: Verwenden Sie für das Öffnen des CSV-Datensatzes nicht Excel, da dieser mehr als 1,25 Millionen Zeilen enthält. Excel wird eine Fehlermeldung anzeigen und darauf hinweisen, dass der Datensatz nicht vollständig geladen wurde. Erläuterungen zu den Daten und zu den Erhebungen finden Sie im Excel-Datensatz weiter unten auf dieser Website.
# Issued                   : 2019-11-29T00:00:00
# Modified                 : 2021-10-21T00:00:00
# Rights                   : NonCommercialAllowed-CommercialWithPermission-ReferenceRequired

df = get_dataset('https://www.bfs.admin.ch/bfsstatic/dam/assets/11027921/master')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: auskunftsdienst@bfs.admin.ch | info@bfs.admin.ch
