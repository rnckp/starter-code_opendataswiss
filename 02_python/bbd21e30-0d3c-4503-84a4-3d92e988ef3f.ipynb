# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **848ed8e3-d184-4689-889a-c28178942ece@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten 2022 der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die Daten des Jahres **2022**. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-2022-der-vbz-im-soll-ist-vergleich-nachfuhrung-eingestellt)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022)

# %% [markdown]
# ## Metadata
# - **Publisher** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['hackzurich', 'verspatung', 'sachdaten', 'bus', 'tram', 'punktlichkeit', 'tabelle', 'offentlicher-verkehr', 'vbz']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2023-11-21T02:47:27.088448`
# - **Metadata_modified** `2024-01-23T02:51:46.249174`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`54` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:33:31.216179
# Modified                 : 2023-11-24T20:43:02.623315
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221023_20221029.csv')

# Distribution 1
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:28:10.581179
# Modified                 : 2023-11-24T20:24:37.086423
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220515_20220521.csv')

# Distribution 2
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:30:54.006620
# Modified                 : 2023-11-24T20:34:40.554816
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220807_20220813.csv')

# Distribution 3
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:24:11.121886
# Modified                 : 2023-11-24T20:11:01.249772
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220109_20220115.csv')

# Distribution 4
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:26:52.711755
# Modified                 : 2023-11-24T20:20:16.683456
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220116_20220122.csv')

# Distribution 31
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:28:23.104039
# Modified                 : 2023-11-24T20:25:06.447317
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220522_20220528.csv')

# Distribution 32
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:28:50.028240
# Modified                 : 2023-11-24T20:26:36.356270
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220605_20220611.csv')

# Distribution 33
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:26:13.454101
# Modified                 : 2023-11-24T20:17:57.136539
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220313_20220319.csv')

# Distribution 34
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:27:30.599328
# Modified                 : 2023-11-24T20:22:37.784542
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220424_20220430.csv')

# Distribution 35
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:32:07.591377
# Modified                 : 2023-11-24T20:38:34.439453
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220911_20220917.csv')

# Distribution 36
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:24:30.877960
# Modified                 : 2023-11-24T20:12:22.042671
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220123_20220129.csv')

# Distribution 37
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:30:13.576799
# Modified                 : 2023-11-24T20:32:24.291764
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220717_20220723.csv')

# Distribution 38
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:34:25.375050
# Modified                 : 2023-11-24T20:45:55.932245
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221120_20221126.csv')

# Distribution 39
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:25:21.307320
# Modified                 : 2023-11-24T20:15:19.470383
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220220_20220226.csv')

# Distribution 40
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:34:54.607059
# Modified                 : 2023-11-24T20:47:22.460773
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221204_20221210.csv')

# Distribution 41
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:28:37.404836
# Modified                 : 2023-11-24T20:25:51.150505
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220529_20220604.csv')

# Distribution 42
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:33:57.359425
# Modified                 : 2023-11-24T20:44:28.287023
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221106_20221112.csv')

# Distribution 43
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:25:35.730143
# Modified                 : 2023-11-24T20:16:25.933518
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220227_20220305.csv')

# Distribution 44
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:31:38.989901
# Modified                 : 2023-11-24T20:37:05.944091
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220828_20220903.csv')

# Distribution 45
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:35:09.476583
# Modified                 : 2023-11-24T20:48:05.556576
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221211_20221217.csv')

# Distribution 46
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:27:57.384486
# Modified                 : 2023-11-24T20:24:04.778104
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220508_20220514.csv')

# Distribution 47
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:30:26.756780
# Modified                 : 2023-11-24T20:33:08.247848
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220724_20220730.csv')

# Distribution 48
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:32:49.893971
# Modified                 : 2023-11-24T20:40:52.864337
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221002_20221008.csv')

# Distribution 49
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:26:39.768231
# Modified                 : 2023-11-24T20:19:26.430167
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220327_20220402.csv')

# Distribution 50
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:35:47.408593
# Modified                 : 2023-11-24T20:49:35.844075
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20221225_20221231.csv')

# Distribution 51
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:24:43.316987
# Modified                 : 2023-11-24T20:13:05.543907
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220130_20220205.csv')

# Distribution 52
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:30:40.910063
# Modified                 : 2023-11-24T20:33:57.244161
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220731_20220806.csv')

# Distribution 53
# Package_id               : bbd21e30-0d3c-4503-84a4-3d92e988ef3f
# Description              : 
# Issued                   : 2023-11-21T19:29:57.958375
# Modified                 : 2023-11-24T20:30:36.730349
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2022/download/Fahrzeiten_SOLL_IST_20220710_20220716.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
