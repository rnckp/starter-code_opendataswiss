# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Auto-generated Python starter code for the dataset with identifier* **ScenariosParBranche2060@bundesamt-fur-raumentwicklung-are**

# %% [markdown]
# ## Dataset
# # **Branchenszenarien 2022-2060**

# %% [markdown]
# ## Description
#
# Im Auftrag der Bundesämter für Raumentwicklung (ARE) und für Energie (BFE) wurden die Branchenszenarien im September 2025 aktualisiert. Diese Szenarien zeigen auf, wie sich die Wirtschaftsstruktur der Schweiz bis 2060 entwickeln könnte. Sie stützen sich auf ein Modell, das die Interaktionen zwischen den einzelnen Branchen und zwischen Produzentinnen und Produzenten sowie Kosumentinnen und Konsumenten berücksichtigt. Zudem trägt es den Entwicklungen auf nationaler wie auch auf regionaler Ebene Rechnung. Als Grundlagen wurden die Szenarien für die Bevölkerungsentwicklung und die demografische Alterung (Bundesamt für Statistik BFS) beziehungsweise für die Entwicklung des Bruttoinlandprodukts (BIP) des SECO herangezogen. Sämtliche verwendeten Daten sowie die Annahmen und Ergebnisse sind online verfügbar. In den Datensets enthalten sind namentlich Angaben zur Beschäftigung, zur Wertschöpfung und zum Produktionsvolumen für 46 Branchen, und zwar für jedes Jahr im Zeitraum 2017 bis 2060 sowie aufgeschlüsselt nach Arbeitsmarktregionen, MS-Regionen und Kantonen.

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/scenarios-par-branche-2060-branchenszenarien-2060)<br>
# [Direct link by Bundesamt für Raumentwicklung ARE for dataset](https://doi.org/10.5281/zenodo.17086416)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `nan`
# - **Organization.display_name.de** `Bundesamt für Raumentwicklung ARE`
# - **Organization.url** ``
# - **Maintainer** `Joséphine Leuba`
# - **Maintainer_email** `josephine.leuba@are.admin.ch`
# - **Keywords.de** `['beschaftigung', 'branchenszenarien', 'wertschopfung', 'wirtschaft']`
# - **Issued** `2020-11-27T00:00:00`
# - **Metadata_created** `2020-12-01T06:38:35.415627`
# - **Metadata_modified** `2025-10-23T06:01:38.622593`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with the proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If the dataframe only has one column or less, the data is not comma separated; use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`5` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 3137575f-f4d5-476d-9447-0dc26fdb1014
# Description              : 
# Issued                   : 2025-09-22T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://zenodo.org/records/17086416/files/rn1b_cli.csv?download=1')

# Distribution 1
# Package_id               : 3137575f-f4d5-476d-9447-0dc26fdb1014
# Description              : 
# Issued                   : 2025-09-22T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://zenodo.org/records/17086416/files/rdub_cli.csv?download=1')

# Distribution 2
# Package_id               : 3137575f-f4d5-476d-9447-0dc26fdb1014
# Description              : 
# Issued                   : 2025-09-22T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://zenodo.org/records/17086416/files/rdlb_cli.csv?download=1')

# Distribution 3
# Package_id               : 3137575f-f4d5-476d-9447-0dc26fdb1014
# Description              : 
# Issued                   : 2025-09-22T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://zenodo.org/records/17086416/files/dn1b_cli.csv?download=1')

# Distribution 4
# Package_id               : 3137575f-f4d5-476d-9447-0dc26fdb1014
# Description              : 
# Issued                   : 2025-09-22T00:00:00
# Modified                 : 
# Rights                   : None

df = get_dataset('https://zenodo.org/records/17086416/files/gn1b_cli.csv?download=1')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: Joséphine Leuba | josephine.leuba@are.admin.ch
