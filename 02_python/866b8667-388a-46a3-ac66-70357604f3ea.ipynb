# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for dataset with identifier* **5591a292-8d0e-4ba1-b579-85382339b5bb@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten 2018 der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die Daten des Jahres 2018. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) und die des aktuellen Jahres finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Dataset links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-2018-der-vbz-im-soll-ist-vergleich-nachfuhrung-eingestellt1)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['bus', 'hackzurich', 'offentlicher-verkehr', 'punktlichkeit', 'sachdaten', 'tabelle', 'tram', 'vbz', 'verspatung']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2025-11-06T02:46:24.817401`
# - **Metadata_modified** `2025-12-19T01:54:10.965988`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`56` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:27:46.872068
# Modified                 : 2025-05-11T20:27:46.825816
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20171231_20180106.csv')

# Distribution 1
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:27:56.406559
# Modified                 : 2025-05-11T20:27:56.340909
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180107_20180113.csv')

# Distribution 2
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:06.669977
# Modified                 : 2025-05-11T20:28:06.623313
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180114_20180120.csv')

# Distribution 3
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:16.216807
# Modified                 : 2025-05-11T20:28:16.158702
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180121_20180127.csv')

# Distribution 4
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:27.191515
# Modified                 : 2025-05-11T20:28:27.133387
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180128_20180203.csv')

# Distribution 5
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:39.880772
# Modified                 : 2025-05-11T20:28:39.818297
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180204_20180210.csv')

# Distribution 6
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:49.867850
# Modified                 : 2025-05-11T20:28:49.428902
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180211_20180217.csv')

# Distribution 7
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:28:59.637915
# Modified                 : 2025-05-11T20:28:59.581463
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180218_20180224.csv')

# Distribution 8
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:29:10.055877
# Modified                 : 2025-05-11T20:29:09.974924
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180225_20180303.csv')

# Distribution 9
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:39:13.569452
# Modified                 : 2025-05-11T20:39:13.437921
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180812_20180818.csv')

# Distribution 34
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:39:24.893671
# Modified                 : 2025-05-11T20:39:24.355850
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180819_20180825.csv')

# Distribution 35
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:39:36.997281
# Modified                 : 2025-05-11T20:39:36.878975
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180826_20180901.csv')

# Distribution 36
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:39:47.917817
# Modified                 : 2025-05-11T20:39:47.809980
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180902_20180908.csv')

# Distribution 37
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:03.154040
# Modified                 : 2025-05-11T20:40:02.973332
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180909_20180915.csv')

# Distribution 38
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:14.909425
# Modified                 : 2025-05-11T20:40:14.778025
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180916_20180922.csv')

# Distribution 39
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:25.959948
# Modified                 : 2025-05-11T20:40:25.411994
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180923_20180929.csv')

# Distribution 40
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:38.971411
# Modified                 : 2025-05-11T20:40:38.850896
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20180930_20181006.csv')

# Distribution 41
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:48.139634
# Modified                 : 2025-05-11T20:40:48.014455
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181007_20181013.csv')

# Distribution 42
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:40:57.700758
# Modified                 : 2025-05-11T20:40:57.570374
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181014_20181020.csv')

# Distribution 43
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:42:54.353528
# Modified                 : 2025-05-11T20:42:54.169701
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181021_20181027.csv')

# Distribution 44
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:06.278088
# Modified                 : 2025-05-11T20:43:06.147725
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181028_20181103.csv')

# Distribution 45
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:17.754937
# Modified                 : 2025-05-11T20:43:17.213902
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181104_20181110.csv')

# Distribution 46
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:26.725053
# Modified                 : 2025-05-11T20:43:26.555744
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181111_20181117.csv')

# Distribution 47
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:36.749782
# Modified                 : 2025-05-11T20:43:36.611567
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181118_20181124.csv')

# Distribution 48
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:46.401949
# Modified                 : 2025-05-11T20:43:46.273106
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181125_20181201.csv')

# Distribution 49
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:43:58.166442
# Modified                 : 2025-05-11T20:43:58.025557
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181202_20181208.csv')

# Distribution 50
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:44:07.952545
# Modified                 : 2025-05-11T20:44:07.776527
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181209_20181215.csv')

# Distribution 51
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:46:02.676011
# Modified                 : 2025-05-11T20:46:02.499787
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181216_20181222.csv')

# Distribution 52
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:46:19.356786
# Modified                 : 2025-05-11T20:46:19.206079
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181223_20181229.csv')

# Distribution 53
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:46:29.581139
# Modified                 : 2025-05-11T20:46:29.024739
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Fahrzeiten_SOLL_IST_20181230_20190105.csv')

# Distribution 54
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:46:38.308822
# Modified                 : 2025-05-11T20:46:38.154853
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Haltepunkt.csv')

# Distribution 55
# Package_id               : 866b8667-388a-46a3-ac66-70357604f3ea
# Description              : 
# Issued                   : 2025-05-11T20:46:40.191345
# Modified                 : 2025-05-11T20:46:40.029105
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2018/download/Haltestelle.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
