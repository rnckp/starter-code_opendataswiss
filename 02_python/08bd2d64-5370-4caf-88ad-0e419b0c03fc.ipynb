# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **43383bdd-c889-45f4-93ae-1ffe39d9cf42@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Fahrzeiten 2017 der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**

# %% [markdown]
# ## Description
#
# Diese Daten ermöglichen einen sehr genauen Vergleich zwischen den geplanten (SOLL) und den effektiv erfolgten (IST) Fahrzeiten jedes Fahrzeugs der Verkehrsbetriebe Zürich (VBZ). Die Haltestellenankünfte und -abfahrten jedes Fahrzeugs auf seiner Linie wird sekundengenau gemessen.
#
# Wir publizieren jede Woche einen neuen Datensatz  zu den geplanten (SOLL) und effektiven (IST) Fahrzeiten, da das Datenvolumen sonst schnell zu gross wird. Ein Datensatz einer Woche umfasst rund 250 MB. Die Dateinamen zeigen den Zeitraum der Fahrzeitenvergleiche an: «Fahrzeiten_SOLL_IST_***VON-DATUM***_***BIS-DATUM***.csv».
#
# Die beiden Tabellen ***Haltepunkt.csv*** und ***Haltestelle.csv*** sind Matchingtabellen.
#
# Hier finden Sie die Daten des Jahres 2017. Die wöchentlich nachgeführten Fahrzeiten der vergangenen Jahre (seit 2015) und die des aktuellen Jahres finden sie in den Datasets «[**Fahrzeiten *[JAHR]* der VBZ im SOLL-IST-Vergleich (Nachführung eingestellt)**](https://data.stadt-zuerich.ch/dataset?q=%22SOLL-IST-Vergleich%22&sort=title_string+desc)».

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/fahrzeiten-2017-der-vbz-im-soll-ist-vergleich-nachfuhrung-eingestellt2)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017)

# %% [markdown]
# ## Metadata
# - **Publisher** `Verkehrsbetriebe Zürich, Departement der Industriellen Betriebe`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['punktlichkeit', 'offentlicher-verkehr', 'vbz', 'sachdaten', 'tram', 'tabelle', 'hackzurich', 'bus', 'verspatung']`
# - **Issued** `2015-11-11T00:00:00`
# - **Metadata_created** `2023-11-21T02:46:14.408017`
# - **Metadata_modified** `2025-03-08T03:20:34.001454`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`54` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:50:35.798219
# Modified                 : 2024-11-29T13:29:14.185782
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170115_20170121.csv')

# Distribution 1
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170820_20170826.csv')

# Distribution 34
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T18:01:51.101952
# Modified                 : 2024-11-29T13:39:52.433304
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20171126_20171202.csv')

# Distribution 35
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:52:38.490651
# Modified                 : 2024-11-29T13:31:27.234581
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170319_20170325.csv')

# Distribution 36
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:51:54.235018
# Modified                 : 2024-11-29T13:30:40.048472
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170226_20170304.csv')

# Distribution 37
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:55:11.087231
# Modified                 : 2024-11-29T13:33:52.876006
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170528_20170603.csv')

# Distribution 38
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:54:08.414416
# Modified                 : 2024-11-29T13:32:55.794016
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170430_20170506.csv')

# Distribution 39
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T18:02:06.764864
# Modified                 : 2024-11-29T13:40:07.745907
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20171203_20171209.csv')

# Distribution 40
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:59:43.058618
# Modified                 : 2024-11-29T13:38:10.376538
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20171001_20171007.csv')

# Distribution 41
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:54:35.585664
# Modified                 : 2024-11-29T13:33:22.753148
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170514_20170520.csv')

# Distribution 42
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:57:46.191679
# Modified                 : 2024-11-29T13:36:16.451340
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170806_20170812.csv')

# Distribution 43
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:51:28.372669
# Modified                 : 2024-11-29T13:30:10.455222
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170212_20170218.csv')

# Distribution 44
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:55:24.300683
# Modified                 : 2024-11-29T13:34:05.434264
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170604_20170610.csv')

# Distribution 45
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:55:49.901652
# Modified                 : 2024-11-29T13:34:33.335646
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170618_20170624.csv')

# Distribution 46
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:56:28.785450
# Modified                 : 2024-11-29T13:35:04.032748
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170702_20170708.csv')

# Distribution 47
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:52:11.505841
# Modified                 : 2024-11-29T13:30:56.526092
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170305_20170311.csv')

# Distribution 48
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:59:28.866597
# Modified                 : 2024-11-29T13:37:54.190190
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170924_20170930.csv')

# Distribution 49
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:53:49.488611
# Modified                 : 2024-11-29T13:32:42.571879
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170423_20170429.csv')

# Distribution 50
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:56:43.063065
# Modified                 : 2024-11-29T13:35:16.925639
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170709_20170715.csv')

# Distribution 51
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T18:03:06.262159
# Modified                 : 2024-11-29T13:40:53.189404
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Haltepunkt.csv')

# Distribution 52
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T17:54:48.804227
# Modified                 : 2024-11-29T13:33:37.489647
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20170521_20170527.csv')

# Distribution 53
# Package_id               : 08bd2d64-5370-4caf-88ad-0e419b0c03fc
# Description              : 
# Issued                   : 2023-11-21T18:00:14.768039
# Modified                 : 2024-11-29T13:38:33.872110
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/vbz_fahrzeiten_ogd_2017/download/Fahrzeiten_SOLL_IST_20171015_20171021.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
