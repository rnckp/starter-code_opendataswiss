# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **7a424d7d-d203-44f7-88c4-552c6c3f3429@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Verkehrszähldaten an der Stampfenbachstrasse nach Fahrzeugtypen, 2007-2023 [Nachführung eingestellt]**

# %% [markdown]
# ## Description
#
#
# Dieses Dataset umfasst die Verkehrszahlen an der Stampfenbachstrasse von 2007 bis 2023, aufgeteilt in Jahresdateien. Die Messung findet mittels Radardetektoren statt. Es wird die Länge des vorbeifahrenden Fahrzeugs gemessen. Aufgrund der Länge wird das Fahrzeug einer von 3 Klassen (0-2.7m = 2R, 2.7-7m = PW, 7-25m = LKW) zugeteilt. Die Zählstelle befindet sich auf der Höhe der Berufsschule für Detailhandel Zürich direkt neben dem Parkhaus Unterstrasse.
# Während den Bauarbeiten an der Stampfenbachstrasse in den Jahren 2018 und 2019 sind die Verkehrszahlen nicht erfasst worden.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/verkehrszahldaten-an-der-stampfenbachstrasse-nach-fahrzeugtypen-2007-2023-nachfuhrung-eingestel)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['zeitreihe', 'echtzeit', 'tabelle', 'fahrzeugtypen', 'mobilitaet', 'sachdaten', 'verkehr', 'miv']`
# - **Issued** `2020-10-21T00:00:00`
# - **Metadata_created** `2024-11-28T02:50:04.877941`
# - **Metadata_modified** `2025-08-22T02:27:27.337204`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`17` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:45.748880
# Modified                 : 2025-08-22T00:50:37.089626
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2011.csv')

# Distribution 1
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:58.596812
# Modified                 : 2025-08-22T00:51:02.625630
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2023.csv')

# Distribution 2
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:49.893605
# Modified                 : 2025-08-22T00:50:46.070359
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2015.csv')

# Distribution 3
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:54.953693
# Modified                 : 2025-08-22T00:50:56.720345
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2020.csv')

# Distribution 4
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:53.054320
# Modified                 : 2025-08-22T00:50:52.456527
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2018.csv')

# Distribution 5
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:56.158600
# Modified                 : 2025-08-22T00:50:58.736516
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2021.csv')

# Distribution 6
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:51.979697
# Modified                 : 2025-08-22T00:50:50.297270
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2017.csv')

# Distribution 7
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:42.361235
# Modified                 : 2025-08-22T00:50:28.744091
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2007.csv')

# Distribution 8
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:47.051540
# Modified                 : 2025-08-22T00:50:39.226219
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2012.csv')

# Distribution 9
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:43.802256
# Modified                 : 2025-08-22T00:50:32.978903
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2009.csv')

# Distribution 10
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:51.070719
# Modified                 : 2025-08-22T00:50:48.023927
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2016.csv')

# Distribution 11
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:54.051711
# Modified                 : 2025-08-22T00:50:54.363803
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2019.csv')

# Distribution 12
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:43.021098
# Modified                 : 2025-08-22T00:50:30.524042
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2008.csv')

# Distribution 13
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:57.455805
# Modified                 : 2025-08-22T00:51:00.663501
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2022.csv')

# Distribution 14
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:48.987242
# Modified                 : 2025-08-22T00:50:43.913303
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2014.csv')

# Distribution 15
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:48.092949
# Modified                 : 2025-08-22T00:50:41.383881
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2013.csv')

# Distribution 16
# Package_id               : 23b3d1de-cc12-415a-8457-0e3788d735c6
# Description              : 
# Issued                   : 2024-11-27T11:17:44.873107
# Modified                 : 2025-08-22T00:50:35.061772
# Rights                   : https://opendata.swiss/terms-of-use#terms_open

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_verkehrsdaten_stundenwerte_stampfenbachstrasse/download/ugz_ogd_traffic_h1_2010.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@zuerich.ch | Open Data Zürich
