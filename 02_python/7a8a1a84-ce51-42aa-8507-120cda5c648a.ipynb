# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **ist-daten-v2@oevch**

# %% [markdown]
# ## Dataset
# # **Ist-Daten v2**

# %% [markdown]
# ## Description
#
# Die Ist-Daten enthalten die effektiv gefahrenen Fahrten des letzten bzw. des entsprechenden Tages. Die Ist-Daten sind entweder effektive Ist-Daten oder die letzte Prognose, die das Kundeninformationssystem erhalten hat. Wenn keine Echtzeitinformationen vorhanden waren, so fehlt die entsprechende Fahrt.
#
# Dies ist die neue **Version 2** des Datensatzes:
#
# - sie enthält auch Daten mit ausländischen Haltestellen (BPUIC nicht mit 85 beginnend) und für Haltestellen mit einer SLOID als BPIUC.
#
# - das Feld BPUIC kann 7-stellig (herkömmliche Haltestellen-Code), 9-stellig (2 zusätzliche Stellen für Gleis/Haltekanten), oder eine SLOID (15+ Stellen) sein.
#
# Die alte, erste Version ist diese: https://data.opentransportdata.swiss/dataset/istdaten
#
# Ist-Daten Archiv: https://archive.opentransportdata.swiss/actual_data_archive.htm

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/ist-daten-v2)<br>
# [Direct link by Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG) for dataset](https://data.opentransportdata.swiss/dataset/ist-daten-v2)

# %% [markdown]
# ## Metadata
# - **Publisher.name** `CUS`
# - **Organization.display_name.de** `Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG)`
# - **Organization.url** `https://www.opentransportdata.swiss`
# - **Maintainer** `None`
# - **Maintainer_email** `None`
# - **Keywords.de** `['passagier', 'daten', 'punktlichkeit', 'ist-daten', 'embag', 'prognose', 'bus', 'verspatung', 'proprietar', 'zug']`
# - **Issued** `2025-07-28T16:37:00`
# - **Metadata_created** `2025-07-29T01:56:54.209194`
# - **Metadata_modified** `2025-08-13T01:41:47.558229`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`30` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:36:49.544262
# Modified                 : 2025-07-28T11:36:49.544262
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/7223f655-7139-4845-8955-5b55de6d80e2/download/2025-07-25_istdaten.csv')

# Distribution 1
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:40:08.804464
# Modified                 : 2025-07-28T11:40:08.804464
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/55e8e76f-c7a4-4aba-b9d2-8bda5052d597/download/2025-07-27_istdaten.csv')

# Distribution 2
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-31T01:16:50.103911
# Modified                 : 2025-07-31T01:16:50.103911
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/64fe2a00-7f67-49ae-957f-cdc340ee4d49/download/2025-07-30_istdaten.csv')

# Distribution 3
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-03T01:02:15.148261
# Modified                 : 2025-08-03T01:02:15.148261
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/c4b79f5f-ae54-48f9-ab58-7b396a0172bf/download/2025-08-02_istdaten.csv')

# Distribution 4
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:13:24.897580
# Modified                 : 2025-07-28T11:13:24.897580
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/ec6d6edf-3556-4a5c-9156-77bbca63d69f/download/2025-07-14_istdaten.csv')

# Distribution 5
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:15:32.723442
# Modified                 : 2025-07-28T11:15:32.723442
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/79bfc7f0-6bbd-4eb4-8aef-c89dd7a40816/download/2025-07-15_istdaten.csv')

# Distribution 6
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-09T01:32:14.065356
# Modified                 : 2025-08-09T01:32:14.065356
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/5ed61a0c-622a-4a95-9fc1-def2784c1962/download/2025-08-08_istdaten.csv')

# Distribution 7
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:17:50.169847
# Modified                 : 2025-07-28T11:17:50.169847
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/ff329fe5-4038-4b78-9717-5a60a9bead0f/download/2025-07-16_istdaten.csv')

# Distribution 8
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:26:07.406940
# Modified                 : 2025-07-28T11:26:07.406940
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/f98963e0-7b6b-42b2-916f-740fe1d7417b/download/2025-07-20_istdaten.csv')

# Distribution 9
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-02T01:26:51.998886
# Modified                 : 2025-08-02T01:26:51.998886
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/21a4cfb0-a897-428b-b890-6949c76eb0bb/download/2025-08-01_istdaten.csv')

# Distribution 10
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:32:37.938910
# Modified                 : 2025-07-28T11:32:37.938910
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/3e59ff2d-f69d-4e2a-b1bc-cdada4989aaf/download/2025-07-23_istdaten.csv')

# Distribution 11
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-08T06:08:10.958139
# Modified                 : 2025-08-08T06:08:10.958139
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/a7eae5c0-6701-4732-bf88-42d827e87923/download/2025-08-07_istdaten.csv')

# Distribution 12
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-05T01:02:28.335869
# Modified                 : 2025-08-05T01:02:28.335869
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/08b78c88-0fc1-4b96-a440-db8be26f23c0/download/2025-08-04_istdaten.csv')

# Distribution 13
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-07T01:16:51.415844
# Modified                 : 2025-08-07T01:16:51.415844
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/88f2965d-d5c6-4df9-bb64-25bbb3bf4c4b/download/2025-08-06_istdaten.csv')

# Distribution 14
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:38:45.565515
# Modified                 : 2025-07-28T11:38:45.565515
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/44f12ad8-5f68-4ba7-8e35-3c632d47f71f/download/2025-07-26_istdaten.csv')

# Distribution 15
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-06T01:32:09.146433
# Modified                 : 2025-08-06T01:32:09.146433
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/293e7a85-4112-4a46-8b56-a382db18fdd8/download/2025-08-05_istdaten.csv')

# Distribution 16
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:28:19.331943
# Modified                 : 2025-07-28T11:28:19.331943
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/4298d768-dfae-4b6c-8aaf-ec4fb96cb9c3/download/2025-07-21_istdaten.csv')

# Distribution 17
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-10T01:02:17.002652
# Modified                 : 2025-08-10T01:02:17.002652
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/8953f67f-6c8e-4776-b0f2-86ae8aab9de2/download/2025-08-09_istdaten.csv')

# Distribution 18
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:34:40.933195
# Modified                 : 2025-07-28T11:34:40.933195
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/618d8534-12d2-4964-95be-185963a62592/download/2025-07-24_istdaten.csv')

# Distribution 19
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:20:01.669844
# Modified                 : 2025-07-28T11:20:01.669844
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/bb7f5e04-317c-42bd-a71e-994bb8d177af/download/2025-07-17_istdaten.csv')

# Distribution 20
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:11:17.006451
# Modified                 : 2025-07-28T11:11:17.006451
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/5004ba26-705a-44d6-b1e5-792e61b1f7c1/download/2025-07-13_istdaten.csv')

# Distribution 21
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-01T01:46:50.290655
# Modified                 : 2025-08-01T01:46:50.290655
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/0e64eb39-738e-4fc3-a13e-b5d4942fb888/download/2025-07-31_istdaten.csv')

# Distribution 22
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-29T02:03:53.268138
# Modified                 : 2025-07-29T02:03:53.268138
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/5dc097fa-93d0-472f-b6f0-e5e26e3b47a2/download/2025-07-28_istdaten.csv')

# Distribution 23
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-12T01:06:56.681734
# Modified                 : 2025-08-12T01:06:56.681734
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/c1fb100e-4109-49c8-9c69-ac753f3fa6cf/download/2025-08-11_istdaten.csv')

# Distribution 24
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-11T01:21:13.783727
# Modified                 : 2025-08-11T01:21:13.783727
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/7491bdec-fee4-41d0-a82b-4111dc00cc1b/download/2025-08-10_istdaten.csv')

# Distribution 25
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-30T01:36:50.931074
# Modified                 : 2025-07-30T01:36:50.931074
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/722dd558-f677-4a53-b60f-e0fa7c5d01b3/download/2025-07-29_istdaten.csv')

# Distribution 26
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:30:27.693123
# Modified                 : 2025-07-28T11:30:27.693123
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/8c2eefa8-2e66-4e5e-a249-9e960186a6b5/download/2025-07-22_istdaten.csv')

# Distribution 27
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-08-04T01:26:08.834002
# Modified                 : 2025-08-04T01:26:08.834002
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/94f98d18-3849-4362-8382-65e97f9f36a5/download/2025-08-03_istdaten.csv')

# Distribution 28
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:24:43.025126
# Modified                 : 2025-07-28T11:24:43.025126
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/c8c7751d-32fd-46af-889e-34a2f4398498/download/2025-07-19_istdaten.csv')

# Distribution 29
# Package_id               : 7a8a1a84-ce51-42aa-8507-120cda5c648a
# Description              : 
# Issued                   : 2025-07-28T11:22:41.661619
# Modified                 : 2025-07-28T11:22:41.661619
# Rights                   : https://opendata.swiss/terms-of-use#terms_by

df = get_dataset('https://data.opentransportdata.swiss/dataset/febff1f3-ee85-470a-9487-2d07f93457c1/resource/cd60430a-2d46-4a4f-9109-ad0f6fd7d494/download/2025-07-18_istdaten.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: opendata@sbb.ch | Open Data Mobilität Schweiz
