# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **9e303b80-9c88-407c-b926-e8f2f7eb63da@envidat**

# %% [markdown]
# ## Dataset
# # **Snow water equivalent measurements with low-cost GNSS receivers along a steep elevation gradient in the East-ern Swiss Alps**

# %% [markdown]
# ## Description

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/snow-water-equivalent-measurements-with-low-cost-gnss-receivers-along-a-steep-elevation-gradien)<br>
# [Direct link by EnviDat: das Umwelt-Datenportal for dataset](https://www.envidat.ch/#/metadata/swe-measurements-gnss-along-a-steep-elevation-gradient)

# %% [markdown]
# ## Metadata
# - **Publisher** `EnviDat`
# - **Organization.display_name.de** `EnviDat: das Umwelt-Datenportal`
# - **Organization.url** `https://www.envidat.ch/`
# - **Maintainer** `Achille Capelli`
# - **Maintainer_email** `capelli@slf.ch`
# - **Keywords.de** `[]`
# - **Issued** `2020-10-29T00:00:00`
# - **Metadata_created** `2021-06-15T16:21:03.577442`
# - **Metadata_modified** `2023-01-14T01:15:35.819231`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`18` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/be4ca553-12f8-4a2a-94bc-1672dfbac5b9')

# Distribution 1
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/01d5ba5c-4734-43b0-b1cd-68e97e0fd711')

# Distribution 2
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/4b796a10-3ab7-42c9-ab1f-3d6218692326')

# Distribution 3
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/d18ef060-e61f-4196-82ad-859e3faa1c9b')

# Distribution 4
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/df76c91e-b71e-4441-a905-31b32b8782fb')

# Distribution 5
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/e582db3a-a0ba-4527-9c2f-ca961562c317')

# Distribution 6
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-10-29T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/f791ca79-0c9a-4055-9989-d5176e222935')

# Distribution 7
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/dc102dd3-9d9d-4757-9263-9306c6474b5c')

# Distribution 8
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/8a7318b9-571d-4da9-9686-2330bf0f373a')

# Distribution 9
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/398c7a10-d1bf-4fd3-b7a9-8175843077d7')

# Distribution 10
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/9bb74e8a-d19b-49ca-aecf-feed84c3e324')

# Distribution 11
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/40726e6f-f175-4033-8df7-526e42cdc266')

# Distribution 12
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/e6d6f714-5f1a-4cc9-9ab1-3cf5417073a7')

# Distribution 13
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/0ba3714e-3caa-47d3-8b8c-c235fc57760e')

# Distribution 14
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-10-29T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/973a7cde-cf6e-484e-8da1-a2da1de4fc49')

# Distribution 15
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/ba8b38d2-fcc3-4345-b763-4b618e49836f')

# Distribution 16
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-10-29T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/bc65a02c-f311-49c7-9007-a8df51a87610')

# Distribution 17
# Package_id               : 184500c0-4e04-440f-9f33-4d35489debf6
# Description              : 
# Issued                   : 2020-11-27T00:00:00
# Modified                 : 2020-11-27T00:00:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.envidat.ch/dataset/swe-measurements-gnss-along-a-steep-elevation-gradient/resource/3af4ec59-d2ff-425e-ba49-996cd5a85247')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: envidat@wsl.ch | EnviDat Support
