# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **prm_data@oevch**

# %% [markdown]
# ## Dataset
# # **Bestandsaufnahme BehiG**

# %% [markdown]
# ## Description
#
# Im Rahmen der Behindertengleichstellungsgesetzes (BehiG) sind die konzessionierten Unternehmen des öffentlichen Verkehrs verpflichtet, Daten über die Barrierefreiheit der öV-Haltepunkte zu erfassen. Diese Rohdaten werden hier publiziert.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/bestandsaufnahme-behig)<br>
# [Direct link by Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG) for dataset](https://opentransportdata.swiss/dataset/prm_data)

# %% [markdown]
# ## Metadata
# - **Publisher** `Specialist office Open Data`
# - **Organization.display_name.de** `Geschäftsstelle Systemaufgaben Kundeninformation (SBB AG)`
# - **Organization.url** `https://www.opentransportdata.swiss`
# - **Maintainer** `DiDok Fachstelle`
# - **Maintainer_email** `didok@sbb.ch`
# - **Keywords.de** `['behig', 'prm-data']`
# - **Issued** `2021-03-19T07:15:25.225671`
# - **Metadata_created** `2021-03-20T02:58:35.589811`
# - **Metadata_modified** `2023-05-13T00:30:20.889955`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`8` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Haltekanten. 
# Issued                   : 2021-03-19T07:15:28.455051
# Modified                 : 2023-05-11T01:01:25.241743
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/54414805-c957-4fc8-9398-3b90bd6148ad/download/prm_platforms.csv')

# Distribution 1
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Haltestellen.
# Issued                   : 2021-03-19T07:15:25.225671
# Modified                 : 2023-05-11T01:02:15.704959
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/9c395644-6002-42c3-91c7-9d5ae0036629/download/prm_stop_places.csv')

# Distribution 2
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Billettschaltern.
# Issued                   : 2021-03-19T07:15:36.082458
# Modified                 : 2023-05-11T01:02:44.241754
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/674b9109-7189-441b-91c3-829d365d99de/download/prm_ticket_counters.csv')

# Distribution 3
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Referenzpunkten. 
# Issued                   : 2021-03-19T07:15:26.896484
# Modified                 : 2023-05-11T01:01:50.055419
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/d679e7c1-d64c-4ec4-a1cd-531fe1043361/download/prm_reference_points.csv')

# Distribution 4
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Informationsschaltern.
# Issued                   : 2021-03-19T07:15:34.473576
# Modified                 : 2023-05-11T01:00:32.505432
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/802339a6-58ef-40ba-8b8f-ffc85f37d6d2/download/prm_info_desks.csv')

# Distribution 5
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten zur Zugänglichkeit von Parkplätzen. 
# Issued                   : 2021-03-19T07:15:37.093404
# Modified                 : 2023-05-11T01:00:57.989525
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/3adfc3d5-0a55-44b2-8a44-91d51a5865ad/download/prm_parking_lots.csv')

# Distribution 6
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten betreffend behindertengerechten Toiletten und deren Zugang. 
# Issued                   : 2021-03-19T07:15:29.470226
# Modified                 : 2023-05-11T01:03:08.958873
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/ed95a367-f4db-44d5-bfe9-57e3878d53c7/download/prm_toilets.csv')

# Distribution 7
# Package_id               : 749efe48-a8f6-4912-807a-6e7f666eeb0a
# Description              : Daten über die Zugänglichkeit von Verbindungen zwischen Referenzpunkten und Haltekanten, etc. 
# Issued                   : 2021-03-19T07:15:38.116175
# Modified                 : 2023-05-11T01:00:07.552770
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://opentransportdata.swiss/dataset/a00b9bb8-fb1e-41a3-8280-343c4c0994ce/resource/736452e8-10d6-4b03-8441-f45d7edd8275/download/prm_connections.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Contact**: didok@sbb.ch | DiDok Fachstelle
