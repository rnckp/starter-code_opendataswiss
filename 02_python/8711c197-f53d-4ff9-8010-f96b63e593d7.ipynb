# %% [markdown]
# ## Open Government Data, provided by **opendata.swiss**
# *Autogenerated Python starter code for data set with identifier* **6a8f6d04-d078-4c27-a84c-f3e1bbc420ed@stadt-zurich**

# %% [markdown]
# ## Dataset
# # **Stündlich aktualisierte Luftqualitätsmessungen, seit 1983**

# %% [markdown]
# ## Description
#
#
# Dieses Dataset umfasst **Stundenmesswerte seit 1983 bis zur letzten aktuellen Stunde**, aufgeteilt in Jahresdateien. Darin enthalten sind die **Stundenmittelwerte** des entsprechenden Jahres für die Stationen Stampfenbachstrasse, Schimmelstrasse, Rosengartenstrasse und Heubeeribüel. Gemessen wird Ozon (O3), Stickoxide (NOx), Stickstoffmonoxid (NO), Stickstoffdioxid (NO2), Feinstaub (PM10 und PM2.5), Kohlenmonoxid (CO) und Schwefeldioxid (SO2) wo jeweils in genügender Qualität vorhanden.
#
# Die Stundenmittelwerte des laufenden Jahres werden jeweils 30 Minuten nach der vollen Stunde aktualisiert.

# %% [markdown]
# ## Data set links
#
# [Direct link by opendata.swiss for dataset](https://opendata.swiss/de/dataset/stundlich-aktualisierte-luftqualitatsmessungen-seit-19831)<br>
# [Direct link by Stadt Zürich for dataset](https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte)

# %% [markdown]
# ## Metadata
# - **Publisher** `Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement`
# - **Organization.display_name.de** `Stadt Zürich`
# - **Organization.url** `http://www.stadt-zuerich.ch/opendata`
# - **Maintainer** `Open Data Zürich`
# - **Maintainer_email** `opendata@zuerich.ch`
# - **Keywords.de** `['stickstoffmonoxid', 'luft', 'o3', 'digitale-transparenz-im-oeffentlichen-raum', 'stickstoffdioxid', 'luftqualitat', 'luftschadstoffe', 'dtoer', 'schwefeldioxid', 'tabelle', 'ozon', 'no', 'co', 'kohlenmonoxid', 'no2', 'zeitreihe', 'echtzeit', 'messwerte', 'stickoxide', 'so2', 'pm25', 'feinstaub', 'pm10', 'nox', 'sachdaten', 'schadstoffe']`
# - **Issued** `nan`
# - **Metadata_created** `2022-02-15T02:24:28.879510`
# - **Metadata_modified** `2024-05-05T03:18:49.860948`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`42` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:41:12.511649
# Modified                 : 2024-05-05T01:39:15.689817
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2015.csv')

# Distribution 1
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:36:58.573819
# Modified                 : 2024-05-05T01:39:12.967514
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2014.csv')

# Distribution 2
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:38:35.435862
# Modified                 : 2024-05-05T01:38:46.361655
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2004.csv')

# Distribution 3
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:36:29.739700
# Modified                 : 2024-05-05T01:39:30.869124
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2020.csv')

# Distribution 4
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:36:37.811951
# Modified                 : 2024-05-05T01:38:51.435638
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2006.csv')

# Distribution 5
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:35:52.252071
# Modified                 : 2024-05-05T01:38:23.246073
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1995.csv')

# Distribution 6
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:37:43.417812
# Modified                 : 2024-05-05T01:39:01.957977
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2010.csv')

# Distribution 7
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:41:43.749013
# Modified                 : 2024-05-05T01:38:41.139730
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2002.csv')

# Distribution 8
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:41:21.893598
# Modified                 : 2024-05-05T01:38:56.780639
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2008.csv')

# Distribution 9
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:36:21.655349
# Modified                 : 2024-05-05T01:38:54.275372
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2007.csv')

# Distribution 10
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2021-06-01T14:57:10.110159
# Modified                 : 2024-05-05T01:39:18.785458
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_2016.csv')

# Distribution 11
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12:40:55.679263
# Modified                 : 2024-05-05T01:38:25.656368
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://data.stadt-zuerich.ch/dataset/ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1996.csv')

# Distribution 12
# Package_id               : 8711c197-f53d-4ff9-8010-f96b63e593d7
# Description              : 
# Issued                   : 2020-10-21T12